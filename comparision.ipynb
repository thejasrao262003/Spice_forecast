# %%
import pandas as pd
df = pd.read_csv('Data/aggregated_spice_price_data_2019_2024.csv')
df
# Out:
#       Price Date  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0     2019-10-31              8476.100000              9156.250000
# 1     2019-11-01              8362.619048             10080.666667
# 2     2019-11-02              8228.023256              9744.162791
# 3     2019-11-03              8620.000000              8881.111111
# 4     2019-11-04              8185.625000              9976.950000
# ...          ...                      ...                      ...
# 1822  2024-10-26              9873.513514             11910.000000
# 1823  2024-10-27             10366.666667             10916.666667
# 1824  2024-10-28             10333.593750             11987.500000
# 1825  2024-10-29              9893.684211             11420.263158
# 1826  2024-10-30             10720.000000             10892.857143
#
#       Modal Price (Rs./Quintal)
# 0                   8854.900000
# 1                   9385.238095
# 2                   9147.720930
# ...

# %%
df.columns
# Out:
# Index(['Price Date', 'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal Price (Rs./Quintal)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df['Price Date'] = pd.to_datetime(df['Price Date'])  # Automatically handles YYYY-MM-DD format
df.set_index('Price Date', inplace=True)

# Filter data for the date range from 01-01-2023 to 31-12-2023
start_date = '2023-01-01'
end_date = '2023-12-31'
filtered_df = df.loc[start_date:end_date]

# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(filtered_df.index, filtered_df['Modal Price (Rs./Quintal)'], label='Modal Price (Rs./Quintal)', color='blue')
plt.title('Modal Price Variation Throughout 2023', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
start_date = '2024-01-01'
end_date = '2024-10-31'
filtered_df = df.loc[start_date:end_date]

# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(filtered_df.index, filtered_df['Modal Price (Rs./Quintal)'], label='Modal Price (Rs./Quintal)', color='blue')
plt.title('Modal Price Variation Throughout 2023', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Modal Price (Rs./Quintal)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
