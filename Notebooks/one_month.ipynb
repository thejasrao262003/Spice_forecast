# %%
import pandas as pd
df = pd.read_csv("../Data/aggregated_spice_price_data_2019_2024.csv")
df
# Out:
#       Price Date  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0     2019-10-31              8476.100000              9156.250000
# 1     2019-11-01              8362.619048             10080.666667
# 2     2019-11-02              8228.023256              9744.162791
# 3     2019-11-03              8620.000000              8881.111111
# 4     2019-11-04              8185.625000              9976.950000
# ...          ...                      ...                      ...
# 1822  2024-10-26              9873.513514             11910.000000
# 1823  2024-10-27             10366.666667             10916.666667
# 1824  2024-10-28             10333.593750             11987.500000
# 1825  2024-10-29              9893.684211             11420.263158
# 1826  2024-10-30             10720.000000             10892.857143
#
#       Modal Price (Rs./Quintal)
# 0                   8854.900000
# 1                   9385.238095
# 2                   9147.720930
# 3                   8768.888889
# 4                   9199.375000
# ...                         ...
# 1822               11096.297297
# 1823               10635.166667
# 1824               11361.281250
# 1825               10820.263158
# 1826               10780.000000
#
# [1827 rows x 4 columns]

# %%
df = df[["Price Date", "Modal Price (Rs./Quintal)"]]
df.loc[:, 'Price Date'] = pd.to_datetime(df['Price Date'])
df.set_index('Price Date', inplace=True)
index_dtype = df.index.dtype
print(f"Datatype of the index: {index_dtype}")
# Out:
# Datatype of the index: datetime64[ns]
# /Users/tejas/PycharmProjects/Spice_Price_Forecast/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
import seaborn as sns
color_pal = sns.color_palette()

# %%
df.plot(style='.', figsize=(15, 5), color=color_pal[0], title="Modal Price", )
# Out:
# <Axes: title={'center': 'Modal Price'}, xlabel='Price Date'>

# %%
train_df = df.iloc[df.index<'01-01-2024']
test_df = df.iloc[df.index>='01-01-2024']

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(15, 5))
train_df.plot(ax=ax, label='Training set')
test_df.plot(ax=ax, label='Test set')
plt.show()

# %%
df.iloc[(df.index>'01-01-2020') & (df.index<'01-01-2021')].plot()
# Out:
# <Axes: xlabel='Price Date'>

# %%
df.iloc[(df.index>'01-01-2021') & (df.index<'01-01-2022')].plot()
# Out:
# <Axes: xlabel='Price Date'>

# %%
df.iloc[(df.index>'01-01-2022') & (df.index<'01-01-2023')].plot()
# Out:
# <Axes: xlabel='Price Date'>

# %%
df.iloc[(df.index>'01-01-2023') & (df.index<'01-01-2024')].plot()
# Out:
# <Axes: xlabel='Price Date'>

# %%
import pandas as pd

target_map = df['Modal Price (Rs./Quintal)'].to_dict()

def create_features(df):
    """
    Create time series features based on time series index for weekly forecasting.
    """
    df = df.copy()

    # Time-based features
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['weekofyear'] = df.index.isocalendar().week

    # Lag features
    df['lag30'] = (df.index - pd.Timedelta('30 days')).map(target_map)
    df['lag60'] = (df.index - pd.Timedelta('60 days')).map(target_map)
    df['lag90'] = (df.index - pd.Timedelta('90 days')).map(target_map)

    # Rolling window features
    for window in [30, 60, 90]:
        df[f'rolling_mean_{window}'] = df['Modal Price (Rs./Quintal)'].rolling(window=window, min_periods=1).mean()
        df[f'rolling_median_{window}'] = df['Modal Price (Rs./Quintal)'].rolling(window=window, min_periods=1).median()
        df[f'rolling_std_{window}'] = df['Modal Price (Rs./Quintal)'].rolling(window=window, min_periods=1).std()

    # Exponential moving averages
    df['ema30'] = df['Modal Price (Rs./Quintal)'].ewm(span=30, adjust=False).mean()
    df['ema60'] = df['Modal Price (Rs./Quintal)'].ewm(span=60, adjust=False).mean()

    # Moving averages
    df['moving_avg_30'] = df['Modal Price (Rs./Quintal)'].rolling(window=30, min_periods=1).mean()
    df['moving_avg_60'] = df['Modal Price (Rs./Quintal)'].rolling(window=60, min_periods=1).mean()

    # Other statistical features
    df['max_90'] = df['Modal Price (Rs./Quintal)'].rolling(window=90, min_periods=1).max()
    df['min_90'] = df['Modal Price (Rs./Quintal)'].rolling(window=90, min_periods=1).min()
    df['range_90'] = df['max_90'] - df['min_90']

    return df

# %%
df = create_features(df)
df
# Out:
#             Modal Price (Rs./Quintal)  dayofweek  quarter  month  year  \
# Price Date
# 2019-10-31                8854.900000          3        4     10  2019
# 2019-11-01                9385.238095          4        4     11  2019
# 2019-11-02                9147.720930          5        4     11  2019
# 2019-11-03                8768.888889          6        4     11  2019
# 2019-11-04                9199.375000          0        4     11  2019
# ...                               ...        ...      ...    ...   ...
# 2024-10-26               11096.297297          5        4     10  2024
# 2024-10-27               10635.166667          6        4     10  2024
# 2024-10-28               11361.281250          0        4     10  2024
# 2024-10-29               10820.263158          1        4     10  2024
# 2024-10-30               10780.000000          2        4     10  2024
#
#             dayofyear  weekofyear         lag30         lag60         lag90  \
# Price Date
# 2019-10-31        304          44           NaN           NaN           NaN
# 2019-11-01        305          44           NaN           NaN           NaN
# 2019-11-02        306          44           NaN           NaN           NaN
# 2019-11-03        307          44           NaN           NaN           NaN
# 2019-11-04        308          45           NaN           NaN           NaN
# ...               ...         ...           ...           ...           ...
# 2024-10-26        300          43  11633.807692  11770.400000  11725.500000
# 2024-10-27        301          43  11543.956522  10305.454545  11622.321429
# 2024-10-28        302          44  11568.166667  11413.428571  11389.678571
# 2024-10-29        303          44  12025.500000  11319.857143  11446.545455
# 2024-10-30        304          44  11597.147059  11198.095238  11441.600000
#
#             ...  rolling_mean_90  rolling_median_90  rolling_std_90  \
# Price Date  ...
# 2019-10-31  ...      8854.900000        8854.900000             NaN
# 2019-11-01  ...      9120.069048        9120.069048      375.005663
# 2019-11-02  ...      9129.286342        9147.720930      265.649204
# 2019-11-03  ...      9039.186979        9001.310465      281.989209
# 2019-11-04  ...      9071.224583        9147.720930      254.500444
# ...         ...              ...                ...             ...
# 2024-10-26  ...     11290.763765       11279.369048      620.329062
# 2024-10-27  ...     11279.795379       11277.647783      623.121667
# 2024-10-28  ...     11279.479853       11277.647783      623.072589
# 2024-10-29  ...     11272.521161       11275.683498      624.680971
# 2024-10-30  ...     11265.170049       11273.063853      626.558892
#
#                    ema30         ema60  moving_avg_30  moving_avg_60  \
# Price Date
# 2019-10-31   8854.900000   8854.900000    8854.900000    8854.900000
# 2019-11-01   8889.115361   8872.288134    9120.069048    9120.069048
# 2019-11-02   8905.799591   8881.318718    9129.286342    9129.286342
# 2019-11-03   8896.966643   8877.632494    9039.186979    9039.186979
# 2019-11-04   8916.476859   8888.181428    9071.224583    9071.224583
# ...                  ...           ...            ...            ...
# 2024-10-26  11105.093561  11220.614096   11188.554854   11224.161508
# 2024-10-27  11074.775697  11201.419099   11158.261858   11229.656710
# 2024-10-28  11093.259926  11206.660481   11151.365678   11228.787588
# 2024-10-29  11075.647231  11193.991716   11111.191116   11220.461021
# 2024-10-30  11056.573216  11180.418217   11083.952881   11213.492767
#
#                   max_90       min_90     range_90
# Price Date
# 2019-10-31   8854.900000  8854.900000     0.000000
# 2019-11-01   9385.238095  8854.900000   530.338095
# 2019-11-02   9385.238095  8854.900000   530.338095
# 2019-11-03   9385.238095  8768.888889   616.349206
# 2019-11-04   9385.238095  8768.888889   616.349206
# ...                  ...          ...          ...
# 2024-10-26  14500.000000  8000.000000  6500.000000
# 2024-10-27  14500.000000  8000.000000  6500.000000
# 2024-10-28  14500.000000  8000.000000  6500.000000
# 2024-10-29  14500.000000  8000.000000  6500.000000
# 2024-10-30  14500.000000  8000.000000  6500.000000
#
# [1827 rows x 26 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# Custom metrics
def smape(y_true, y_pred):
    """Symmetric Mean Absolute Percentage Error"""
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

def mdape(y_true, y_pred):
    """Median Absolute Percentage Error"""
    return 100 * np.median(np.abs((y_pred - y_true) / y_true))

def gmrae(y_true, y_pred):
    """Geometric Mean Relative Absolute Error"""
    numerator = np.abs(y_true - y_pred)
    denominator = np.abs(y_true - np.mean(y_true))
    ratio = numerator / denominator
    return np.exp(np.mean(np.log(ratio + 1e-10)))

# Define target and features
y = df['Modal Price (Rs./Quintal)']
feature_columns = [col for col in df.columns if col != 'Modal Price (Rs./Quintal)']
X = df[feature_columns]

# Define the base XGBoost model
xgb_model = XGBRegressor(objective='reg:squarederror', random_state=42)

# Split into 5 sets, each of 30 days
n_splits = 5
test_days = 90

# Calculate total number of splits and test range
total_days = len(y)
split_size = total_days // n_splits

metrics_per_split = []

# Time-based split
for i in range(n_splits):
    # Define train and test indices
    train_end = split_size * (i + 1) - test_days
    test_start = train_end
    test_end = split_size * (i + 1)

    X_train, X_test = X.iloc[:train_end], X.iloc[test_start:test_end]
    y_train, y_test = y.iloc[:train_end], y.iloc[test_start:test_end]

    # Train the model
    xgb_model.fit(X_train, y_train)

    # Predict
    y_pred = xgb_model.predict(X_test)

    # Calculate metrics
    rmse = np.sqrt(mean_absolute_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    smape_val = smape(y_test, y_pred)
    mdape_val = mdape(y_test, y_pred)
    gmrae_val = gmrae(y_test, y_pred)

    metrics_per_split.append({
        'Split': i + 1,
        'RMSE': rmse,
        'MAE': mae,
        'SMAPE': smape_val,
        'MDAPE': mdape_val,
        'GMRAE': gmrae_val
    })

# Print metrics for each split
for metrics in metrics_per_split:
    print(f"Split {metrics['Split']}:")
    for metric_name, metric_value in metrics.items():
        if metric_name != 'Split':
            print(f"  {metric_name}: {metric_value:.4f}")
# Out:
# Split 1:
#   RMSE: 21.0755
#   MAE: 444.1771
#   SMAPE: 5.9186
#   MDAPE: 4.2349
#   GMRAE: 1.2808
# Split 2:
#   RMSE: 15.5721
#   MAE: 242.4900
#   SMAPE: 2.7415
#   MDAPE: 2.0854
#   GMRAE: 0.9003
# Split 3:
#   RMSE: 25.6816
#   MAE: 659.5443
#   SMAPE: 6.1562
#   MDAPE: 5.8404
#   GMRAE: 3.0005
# Split 4:
#   RMSE: 32.5690
#   MAE: 1060.7413
#   SMAPE: 7.0592
#   MDAPE: 5.7980
#   GMRAE: 2.3409
# Split 5:
#   RMSE: 25.0028
#   MAE: 625.1416
#   SMAPE: 5.7198
#   MDAPE: 3.2347
#   GMRAE: 1.9918

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# Assuming `df` contains your data, and it is already prepared with features and target column
# Define train and test data
train_data = df.loc[:'2023-12-31']
test_data = df.loc['2024-01-01':'2024-10-31']

# Extract features and target
feature_columns = [col for col in df.columns if col != 'Modal Price (Rs./Quintal)']
X_train = train_data[feature_columns]
y_train = train_data['Modal Price (Rs./Quintal)']
X_test = test_data[feature_columns]
y_test = test_data['Modal Price (Rs./Quintal)']
model = XGBRegressor(objective='reg:squarederror', random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Add predictions to test data
test_data = test_data.copy()  # Avoid SettingWithCopyWarning
test_data['Predicted'] = y_pred

# Plot
plt.figure(figsize=(14, 7))


# Plot test data (actual values)
plt.plot(test_data.index, test_data['Modal Price (Rs./Quintal)'], label='Test (Actual)', color='green')

# Plot predictions
plt.plot(test_data.index, test_data['Predicted'], label='Predicted', color='red', linestyle='--')

# Add title and labels
plt.title("Train, Test, and Predicted Modal Prices", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Modal Price (Rs./Quintal)", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()

# Metrics Calculation
def smape(y_true, y_pred):
    """Symmetric Mean Absolute Percentage Error"""
    non_zero_mask = (np.abs(y_true) + np.abs(y_pred)) > 0  # Avoid division by zero
    return 100 * np.mean(2 * np.abs(y_pred[non_zero_mask] - y_true[non_zero_mask]) /
                         (np.abs(y_true[non_zero_mask]) + np.abs(y_pred[non_zero_mask])))

def mdape(y_true, y_pred):
    """Median Absolute Percentage Error"""
    non_zero_mask = y_true != 0  # Avoid division by zero
    return 100 * np.median(np.abs((y_pred[non_zero_mask] - y_true[non_zero_mask]) / y_true[non_zero_mask]))

def gmrae(y_true, y_pred):
    """Geometric Mean Relative Absolute Error"""
    numerator = np.abs(y_true - y_pred)
    denominator = np.abs(y_true - np.mean(y_true))
    ratio = numerator / (denominator + 1e-10)  # Avoid division by zero
    return np.exp(np.mean(np.log(ratio + 1e-10)))

mae = mean_absolute_error(y_test, y_pred)
smape_val = smape(y_test.values, y_pred)
mdape_val = mdape(y_test.values, y_pred)
gmrae_val = gmrae(y_test.values, y_pred)

# Print metrics
print("Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Symmetric Mean Absolute Percentage Error (SMAPE): {smape_val:.4f}")
print(f"Median Absolute Percentage Error (MDAPE): {mdape_val:.4f}")
print(f"Geometric Mean Relative Absolute Error (GMRAE): {gmrae_val:.4f}")
# Out:
# Metrics:
# Mean Absolute Error (MAE): 1020.4843
# Symmetric Mean Absolute Percentage Error (SMAPE): 8.3802
# Median Absolute Percentage Error (MDAPE): 7.7101
# Geometric Mean Relative Absolute Error (GMRAE): 1.1795

# %%
import pandas as pd
import numpy as np
from itertools import product
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# Assuming X_train, y_train, X_test, and y_test are defined
# Define the hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [50, 100, 150],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.2]
}

# Generate all combinations of hyperparameters
param_combinations = list(product(
    param_grid['learning_rate'],
    param_grid['max_depth'],
    param_grid['n_estimators'],
    param_grid['subsample'],
    param_grid['colsample_bytree'],
    param_grid['gamma']
))

# Store results for comparison
results = []

# Iterate through each parameter combination
for params in param_combinations:
    # Unpack parameters
    learning_rate, max_depth, n_estimators, subsample, colsample_bytree, gamma = params

    # Define the model with the current parameters
    model = XGBRegressor(
        objective='reg:squarederror',
        learning_rate=learning_rate,
        max_depth=max_depth,
        n_estimators=n_estimators,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        random_state=42
    )

    # Train the model on the training data
    model.fit(X_train, y_train)

    # Predict on the test data
    y_pred = model.predict(X_test)

    # Evaluate performance using MAE
    mae = mean_absolute_error(y_test, y_pred)

    # Save the results
    results.append({
        'learning_rate': learning_rate,
        'max_depth': max_depth,
        'n_estimators': n_estimators,
        'subsample': subsample,
        'colsample_bytree': colsample_bytree,
        'gamma': gamma,
        'mae': mae
    })

    print(f"Evaluated params: {params} | MAE: {mae:.4f}")

# Convert results to a DataFrame for easy analysis
results_df = pd.DataFrame(results)

# Find the best parameters (lowest MAE)
best_params = results_df.loc[results_df['mae'].idxmin()]

# Print the best parameters and corresponding score
print("\nBest Parameters:")
print(best_params)

# Train the final model with the best parameters
final_model = XGBRegressor(
    objective='reg:squarederror',
    learning_rate=best_params['learning_rate'],
    max_depth=int(best_params['max_depth']),
    n_estimators=int(best_params['n_estimators']),
    subsample=best_params['subsample'],
    colsample_bytree=best_params['colsample_bytree'],
    gamma=best_params['gamma'],
    random_state=42
)

final_model.fit(X_train, y_train)
y_pred_final = final_model.predict(X_test)

# Calculate metrics for the final model
final_mae = mean_absolute_error(y_test, y_pred_final)
print(f"\nFinal Model MAE: {final_mae:.4f}")

# Output the final predictions for visualization or further analysis
print("\nFinal Predictions:")
print(pd.DataFrame({'Actual': y_test.values, 'Predicted': y_pred_final}, index=y_test.index).head())
# Out:
# Evaluated params: (0.01, 3, 50, 0.6, 0.6, 0) | MAE: 911.9204
# Evaluated params: (0.01, 3, 50, 0.6, 0.6, 0.1) | MAE: 911.9204
# Evaluated params: (0.01, 3, 50, 0.6, 0.6, 0.2) | MAE: 911.9204
# Evaluated params: (0.01, 3, 50, 0.6, 0.8, 0) | MAE: 917.1785
# Evaluated params: (0.01, 3, 50, 0.6, 0.8, 0.1) | MAE: 917.1785
# Evaluated params: (0.01, 3, 50, 0.6, 0.8, 0.2) | MAE: 917.1785
# Evaluated params: (0.01, 3, 50, 0.6, 1.0, 0) | MAE: 933.2013
# Evaluated params: (0.01, 3, 50, 0.6, 1.0, 0.1) | MAE: 933.2013
# Evaluated params: (0.01, 3, 50, 0.6, 1.0, 0.2) | MAE: 933.2013
# Evaluated params: (0.01, 3, 50, 0.8, 0.6, 0) | MAE: 910.4546
# Evaluated params: (0.01, 3, 50, 0.8, 0.6, 0.1) | MAE: 910.4546
# Evaluated params: (0.01, 3, 50, 0.8, 0.6, 0.2) | MAE: 910.4546
# Evaluated params: (0.01, 3, 50, 0.8, 0.8, 0) | MAE: 912.5358
# Evaluated params: (0.01, 3, 50, 0.8, 0.8, 0.1) | MAE: 912.5358
# Evaluated params: (0.01, 3, 50, 0.8, 0.8, 0.2) | MAE: 912.5358
# Evaluated params: (0.01, 3, 50, 0.8, 1.0, 0) | MAE: 920.4504
# Evaluated params: (0.01, 3, 50, 0.8, 1.0, 0.1) | MAE: 920.4504
# Evaluated params: (0.01, 3, 50, 0.8, 1.0, 0.2) | MAE: 920.4504
# Evaluated params: (0.01, 3, 50, 1.0, 0.6, 0) | MAE: 905.8789
# Evaluated params: (0.01, 3, 50, 1.0, 0.6, 0.1) | MAE: 905.8789
# Evaluated params: (0.01, 3, 50, 1.0, 0.6, 0.2) | MAE: 905.8789
# Evaluated params: (0.01, 3, 50, 1.0, 0.8, 0) | MAE: 908.5481
# Evaluated params: (0.01, 3, 50, 1.0, 0.8, 0.1) | MAE: 908.5481
# Evaluated params: (0.01, 3, 50, 1.0, 0.8, 0.2) | MAE: 908.5481
# Evaluated params: (0.01, 3, 50, 1.0, 1.0, 0) | MAE: 916.1584
# Evaluated params: (0.01, 3, 50, 1.0, 1.0, 0.1) | MAE: 916.1584
# Evaluated params: (0.01, 3, 50, 1.0, 1.0, 0.2) | MAE: 916.1584
# Evaluated params: (0.01, 3, 100, 0.6, 0.6, 0) | MAE: 597.0166
# Evaluated params: (0.01, 3, 100, 0.6, 0.6, 0.1) | MAE: 597.0166
# Evaluated params: (0.01, 3, 100, 0.6, 0.6, 0.2) | MAE: 597.0166
# Evaluated params: (0.01, 3, 100, 0.6, 0.8, 0) | MAE: 605.1933
# Evaluated params: (0.01, 3, 100, 0.6, 0.8, 0.1) | MAE: 605.1933
# Evaluated params: (0.01, 3, 100, 0.6, 0.8, 0.2) | MAE: 605.1933
# Evaluated params: (0.01, 3, 100, 0.6, 1.0, 0) | MAE: 603.6931
# Evaluated params: (0.01, 3, 100, 0.6, 1.0, 0.1) | MAE: 603.6931
# Evaluated params: (0.01, 3, 100, 0.6, 1.0, 0.2) | MAE: 603.6931
# Evaluated params: (0.01, 3, 100, 0.8, 0.6, 0) | MAE: 626.1245
# Evaluated params: (0.01, 3, 100, 0.8, 0.6, 0.1) | MAE: 626.1245
# Evaluated params: (0.01, 3, 100, 0.8, 0.6, 0.2) | MAE: 626.1245
# Evaluated params: (0.01, 3, 100, 0.8, 0.8, 0) | MAE: 625.7081
# Evaluated params: (0.01, 3, 100, 0.8, 0.8, 0.1) | MAE: 625.7081
# Evaluated params: (0.01, 3, 100, 0.8, 0.8, 0.2) | MAE: 625.7081
# Evaluated params: (0.01, 3, 100, 0.8, 1.0, 0) | MAE: 638.3885
# Evaluated params: (0.01, 3, 100, 0.8, 1.0, 0.1) | MAE: 638.3885
# Evaluated params: (0.01, 3, 100, 0.8, 1.0, 0.2) | MAE: 638.3885
# Evaluated params: (0.01, 3, 100, 1.0, 0.6, 0) | MAE: 642.0717
# Evaluated params: (0.01, 3, 100, 1.0, 0.6, 0.1) | MAE: 642.0717
# Evaluated params: (0.01, 3, 100, 1.0, 0.6, 0.2) | MAE: 642.0717
# Evaluated params: (0.01, 3, 100, 1.0, 0.8, 0) | MAE: 633.3259
# Evaluated params: (0.01, 3, 100, 1.0, 0.8, 0.1) | MAE: 633.3259
# Evaluated params: (0.01, 3, 100, 1.0, 0.8, 0.2) | MAE: 633.3259
# Evaluated params: (0.01, 3, 100, 1.0, 1.0, 0) | MAE: 638.2014
# Evaluated params: (0.01, 3, 100, 1.0, 1.0, 0.1) | MAE: 638.2014
# Evaluated params: (0.01, 3, 100, 1.0, 1.0, 0.2) | MAE: 638.2014
# Evaluated params: (0.01, 3, 150, 0.6, 0.6, 0) | MAE: 608.1481
# Evaluated params: (0.01, 3, 150, 0.6, 0.6, 0.1) | MAE: 608.1481
# Evaluated params: (0.01, 3, 150, 0.6, 0.6, 0.2) | MAE: 608.1481
# Evaluated params: (0.01, 3, 150, 0.6, 0.8, 0) | MAE: 597.4071
# Evaluated params: (0.01, 3, 150, 0.6, 0.8, 0.1) | MAE: 597.4071
# Evaluated params: (0.01, 3, 150, 0.6, 0.8, 0.2) | MAE: 597.4071
# Evaluated params: (0.01, 3, 150, 0.6, 1.0, 0) | MAE: 587.2547
# Evaluated params: (0.01, 3, 150, 0.6, 1.0, 0.1) | MAE: 587.2547
# Evaluated params: (0.01, 3, 150, 0.6, 1.0, 0.2) | MAE: 587.2547
# Evaluated params: (0.01, 3, 150, 0.8, 0.6, 0) | MAE: 633.7731
# Evaluated params: (0.01, 3, 150, 0.8, 0.6, 0.1) | MAE: 633.7731
# Evaluated params: (0.01, 3, 150, 0.8, 0.6, 0.2) | MAE: 633.7731
# Evaluated params: (0.01, 3, 150, 0.8, 0.8, 0) | MAE: 624.1012
# Evaluated params: (0.01, 3, 150, 0.8, 0.8, 0.1) | MAE: 624.1012
# Evaluated params: (0.01, 3, 150, 0.8, 0.8, 0.2) | MAE: 624.1012
# Evaluated params: (0.01, 3, 150, 0.8, 1.0, 0) | MAE: 627.2491
# Evaluated params: (0.01, 3, 150, 0.8, 1.0, 0.1) | MAE: 627.2491
# Evaluated params: (0.01, 3, 150, 0.8, 1.0, 0.2) | MAE: 627.2491
# Evaluated params: (0.01, 3, 150, 1.0, 0.6, 0) | MAE: 648.6327
# Evaluated params: (0.01, 3, 150, 1.0, 0.6, 0.1) | MAE: 648.6327
# Evaluated params: (0.01, 3, 150, 1.0, 0.6, 0.2) | MAE: 648.6327
# Evaluated params: (0.01, 3, 150, 1.0, 0.8, 0) | MAE: 640.9985
# Evaluated params: (0.01, 3, 150, 1.0, 0.8, 0.1) | MAE: 640.9985
# Evaluated params: (0.01, 3, 150, 1.0, 0.8, 0.2) | MAE: 640.9985
# Evaluated params: (0.01, 3, 150, 1.0, 1.0, 0) | MAE: 645.6551
# Evaluated params: (0.01, 3, 150, 1.0, 1.0, 0.1) | MAE: 645.6551
# Evaluated params: (0.01, 3, 150, 1.0, 1.0, 0.2) | MAE: 645.6551
# Evaluated params: (0.01, 5, 50, 0.6, 0.6, 0) | MAE: 937.7203
# Evaluated params: (0.01, 5, 50, 0.6, 0.6, 0.1) | MAE: 937.7203
# Evaluated params: (0.01, 5, 50, 0.6, 0.6, 0.2) | MAE: 937.7203
# Evaluated params: (0.01, 5, 50, 0.6, 0.8, 0) | MAE: 956.2773
# Evaluated params: (0.01, 5, 50, 0.6, 0.8, 0.1) | MAE: 956.2773
# Evaluated params: (0.01, 5, 50, 0.6, 0.8, 0.2) | MAE: 956.2773
# Evaluated params: (0.01, 5, 50, 0.6, 1.0, 0) | MAE: 958.7940
# Evaluated params: (0.01, 5, 50, 0.6, 1.0, 0.1) | MAE: 958.7940
# Evaluated params: (0.01, 5, 50, 0.6, 1.0, 0.2) | MAE: 958.7940
# Evaluated params: (0.01, 5, 50, 0.8, 0.6, 0) | MAE: 929.6872
# Evaluated params: (0.01, 5, 50, 0.8, 0.6, 0.1) | MAE: 929.6872
# Evaluated params: (0.01, 5, 50, 0.8, 0.6, 0.2) | MAE: 929.6872
# Evaluated params: (0.01, 5, 50, 0.8, 0.8, 0) | MAE: 925.6315
# Evaluated params: (0.01, 5, 50, 0.8, 0.8, 0.1) | MAE: 925.6315
# Evaluated params: (0.01, 5, 50, 0.8, 0.8, 0.2) | MAE: 925.6315
# Evaluated params: (0.01, 5, 50, 0.8, 1.0, 0) | MAE: 943.2328
# Evaluated params: (0.01, 5, 50, 0.8, 1.0, 0.1) | MAE: 943.2328
# Evaluated params: (0.01, 5, 50, 0.8, 1.0, 0.2) | MAE: 943.2328
# Evaluated params: (0.01, 5, 50, 1.0, 0.6, 0) | MAE: 916.4003
# Evaluated params: (0.01, 5, 50, 1.0, 0.6, 0.1) | MAE: 916.4003
# Evaluated params: (0.01, 5, 50, 1.0, 0.6, 0.2) | MAE: 916.4003
# Evaluated params: (0.01, 5, 50, 1.0, 0.8, 0) | MAE: 921.3263
# Evaluated params: (0.01, 5, 50, 1.0, 0.8, 0.1) | MAE: 921.3263
# Evaluated params: (0.01, 5, 50, 1.0, 0.8, 0.2) | MAE: 921.3263
# Evaluated params: (0.01, 5, 50, 1.0, 1.0, 0) | MAE: 933.0274
# Evaluated params: (0.01, 5, 50, 1.0, 1.0, 0.1) | MAE: 933.0274
# Evaluated params: (0.01, 5, 50, 1.0, 1.0, 0.2) | MAE: 933.0274
# Evaluated params: (0.01, 5, 100, 0.6, 0.6, 0) | MAE: 584.6351
# Evaluated params: (0.01, 5, 100, 0.6, 0.6, 0.1) | MAE: 584.6351
# Evaluated params: (0.01, 5, 100, 0.6, 0.6, 0.2) | MAE: 584.6351
# Evaluated params: (0.01, 5, 100, 0.6, 0.8, 0) | MAE: 591.6025
# Evaluated params: (0.01, 5, 100, 0.6, 0.8, 0.1) | MAE: 591.6025
# Evaluated params: (0.01, 5, 100, 0.6, 0.8, 0.2) | MAE: 591.6025
# Evaluated params: (0.01, 5, 100, 0.6, 1.0, 0) | MAE: 605.6265
# Evaluated params: (0.01, 5, 100, 0.6, 1.0, 0.1) | MAE: 605.6265
# Evaluated params: (0.01, 5, 100, 0.6, 1.0, 0.2) | MAE: 605.6265
# Evaluated params: (0.01, 5, 100, 0.8, 0.6, 0) | MAE: 604.6343
# Evaluated params: (0.01, 5, 100, 0.8, 0.6, 0.1) | MAE: 604.6343
# Evaluated params: (0.01, 5, 100, 0.8, 0.6, 0.2) | MAE: 604.6343
# Evaluated params: (0.01, 5, 100, 0.8, 0.8, 0) | MAE: 617.5917
# Evaluated params: (0.01, 5, 100, 0.8, 0.8, 0.1) | MAE: 617.5917
# Evaluated params: (0.01, 5, 100, 0.8, 0.8, 0.2) | MAE: 617.5917
# Evaluated params: (0.01, 5, 100, 0.8, 1.0, 0) | MAE: 631.1696
# Evaluated params: (0.01, 5, 100, 0.8, 1.0, 0.1) | MAE: 631.1696
# Evaluated params: (0.01, 5, 100, 0.8, 1.0, 0.2) | MAE: 631.1696
# Evaluated params: (0.01, 5, 100, 1.0, 0.6, 0) | MAE: 617.4709
# Evaluated params: (0.01, 5, 100, 1.0, 0.6, 0.1) | MAE: 617.4709
# Evaluated params: (0.01, 5, 100, 1.0, 0.6, 0.2) | MAE: 617.4709
# Evaluated params: (0.01, 5, 100, 1.0, 0.8, 0) | MAE: 647.5202
# Evaluated params: (0.01, 5, 100, 1.0, 0.8, 0.1) | MAE: 647.5202
# Evaluated params: (0.01, 5, 100, 1.0, 0.8, 0.2) | MAE: 647.5202
# Evaluated params: (0.01, 5, 100, 1.0, 1.0, 0) | MAE: 649.1616
# Evaluated params: (0.01, 5, 100, 1.0, 1.0, 0.1) | MAE: 649.1616
# Evaluated params: (0.01, 5, 100, 1.0, 1.0, 0.2) | MAE: 649.1616
# Evaluated params: (0.01, 5, 150, 0.6, 0.6, 0) | MAE: 586.0340
# Evaluated params: (0.01, 5, 150, 0.6, 0.6, 0.1) | MAE: 586.0340
# Evaluated params: (0.01, 5, 150, 0.6, 0.6, 0.2) | MAE: 586.0340
# Evaluated params: (0.01, 5, 150, 0.6, 0.8, 0) | MAE: 570.2138
# Evaluated params: (0.01, 5, 150, 0.6, 0.8, 0.1) | MAE: 570.2138
# Evaluated params: (0.01, 5, 150, 0.6, 0.8, 0.2) | MAE: 570.2138
# Evaluated params: (0.01, 5, 150, 0.6, 1.0, 0) | MAE: 586.2290
# Evaluated params: (0.01, 5, 150, 0.6, 1.0, 0.1) | MAE: 586.2290
# Evaluated params: (0.01, 5, 150, 0.6, 1.0, 0.2) | MAE: 586.2290
# Evaluated params: (0.01, 5, 150, 0.8, 0.6, 0) | MAE: 618.1224
# Evaluated params: (0.01, 5, 150, 0.8, 0.6, 0.1) | MAE: 618.1224
# Evaluated params: (0.01, 5, 150, 0.8, 0.6, 0.2) | MAE: 618.1224
# Evaluated params: (0.01, 5, 150, 0.8, 0.8, 0) | MAE: 632.0169
# Evaluated params: (0.01, 5, 150, 0.8, 0.8, 0.1) | MAE: 632.0169
# Evaluated params: (0.01, 5, 150, 0.8, 0.8, 0.2) | MAE: 632.0169
# Evaluated params: (0.01, 5, 150, 0.8, 1.0, 0) | MAE: 631.9935
# Evaluated params: (0.01, 5, 150, 0.8, 1.0, 0.1) | MAE: 631.9935
# Evaluated params: (0.01, 5, 150, 0.8, 1.0, 0.2) | MAE: 631.9935
# Evaluated params: (0.01, 5, 150, 1.0, 0.6, 0) | MAE: 625.5724
# Evaluated params: (0.01, 5, 150, 1.0, 0.6, 0.1) | MAE: 625.5724
# Evaluated params: (0.01, 5, 150, 1.0, 0.6, 0.2) | MAE: 625.5724
# Evaluated params: (0.01, 5, 150, 1.0, 0.8, 0) | MAE: 659.0960
# Evaluated params: (0.01, 5, 150, 1.0, 0.8, 0.1) | MAE: 659.0960
# Evaluated params: (0.01, 5, 150, 1.0, 0.8, 0.2) | MAE: 659.0960
# Evaluated params: (0.01, 5, 150, 1.0, 1.0, 0) | MAE: 651.0606
# Evaluated params: (0.01, 5, 150, 1.0, 1.0, 0.1) | MAE: 651.0606
# Evaluated params: (0.01, 5, 150, 1.0, 1.0, 0.2) | MAE: 651.0606
# Evaluated params: (0.01, 7, 50, 0.6, 0.6, 0) | MAE: 942.5847
# Evaluated params: (0.01, 7, 50, 0.6, 0.6, 0.1) | MAE: 942.5847
# Evaluated params: (0.01, 7, 50, 0.6, 0.6, 0.2) | MAE: 942.5847
# Evaluated params: (0.01, 7, 50, 0.6, 0.8, 0) | MAE: 947.3578
# Evaluated params: (0.01, 7, 50, 0.6, 0.8, 0.1) | MAE: 947.3578
# Evaluated params: (0.01, 7, 50, 0.6, 0.8, 0.2) | MAE: 947.3578
# Evaluated params: (0.01, 7, 50, 0.6, 1.0, 0) | MAE: 973.2986
# Evaluated params: (0.01, 7, 50, 0.6, 1.0, 0.1) | MAE: 973.2986
# Evaluated params: (0.01, 7, 50, 0.6, 1.0, 0.2) | MAE: 973.2986
# Evaluated params: (0.01, 7, 50, 0.8, 0.6, 0) | MAE: 935.6477
# Evaluated params: (0.01, 7, 50, 0.8, 0.6, 0.1) | MAE: 935.6477
# Evaluated params: (0.01, 7, 50, 0.8, 0.6, 0.2) | MAE: 935.6477
# Evaluated params: (0.01, 7, 50, 0.8, 0.8, 0) | MAE: 933.1510
# Evaluated params: (0.01, 7, 50, 0.8, 0.8, 0.1) | MAE: 933.1510
# Evaluated params: (0.01, 7, 50, 0.8, 0.8, 0.2) | MAE: 933.1510
# Evaluated params: (0.01, 7, 50, 0.8, 1.0, 0) | MAE: 953.7101
# Evaluated params: (0.01, 7, 50, 0.8, 1.0, 0.1) | MAE: 953.7101
# Evaluated params: (0.01, 7, 50, 0.8, 1.0, 0.2) | MAE: 953.7101
# Evaluated params: (0.01, 7, 50, 1.0, 0.6, 0) | MAE: 923.5934
# Evaluated params: (0.01, 7, 50, 1.0, 0.6, 0.1) | MAE: 923.5934
# Evaluated params: (0.01, 7, 50, 1.0, 0.6, 0.2) | MAE: 923.5934
# Evaluated params: (0.01, 7, 50, 1.0, 0.8, 0) | MAE: 930.1297
# Evaluated params: (0.01, 7, 50, 1.0, 0.8, 0.1) | MAE: 930.1297
# Evaluated params: (0.01, 7, 50, 1.0, 0.8, 0.2) | MAE: 930.1297
# Evaluated params: (0.01, 7, 50, 1.0, 1.0, 0) | MAE: 951.0590
# Evaluated params: (0.01, 7, 50, 1.0, 1.0, 0.1) | MAE: 951.0590
# Evaluated params: (0.01, 7, 50, 1.0, 1.0, 0.2) | MAE: 951.0590
# Evaluated params: (0.01, 7, 100, 0.6, 0.6, 0) | MAE: 598.1777
# Evaluated params: (0.01, 7, 100, 0.6, 0.6, 0.1) | MAE: 598.1777
# Evaluated params: (0.01, 7, 100, 0.6, 0.6, 0.2) | MAE: 598.1777
# Evaluated params: (0.01, 7, 100, 0.6, 0.8, 0) | MAE: 616.3857
# Evaluated params: (0.01, 7, 100, 0.6, 0.8, 0.1) | MAE: 616.3857
# Evaluated params: (0.01, 7, 100, 0.6, 0.8, 0.2) | MAE: 616.3857
# Evaluated params: (0.01, 7, 100, 0.6, 1.0, 0) | MAE: 623.0172
# Evaluated params: (0.01, 7, 100, 0.6, 1.0, 0.1) | MAE: 623.0172
# Evaluated params: (0.01, 7, 100, 0.6, 1.0, 0.2) | MAE: 623.0172
# Evaluated params: (0.01, 7, 100, 0.8, 0.6, 0) | MAE: 626.7563
# Evaluated params: (0.01, 7, 100, 0.8, 0.6, 0.1) | MAE: 626.7563
# Evaluated params: (0.01, 7, 100, 0.8, 0.6, 0.2) | MAE: 626.7563
# Evaluated params: (0.01, 7, 100, 0.8, 0.8, 0) | MAE: 661.8464
# Evaluated params: (0.01, 7, 100, 0.8, 0.8, 0.1) | MAE: 661.8464
# Evaluated params: (0.01, 7, 100, 0.8, 0.8, 0.2) | MAE: 661.8464
# Evaluated params: (0.01, 7, 100, 0.8, 1.0, 0) | MAE: 664.1796
# Evaluated params: (0.01, 7, 100, 0.8, 1.0, 0.1) | MAE: 664.1796
# Evaluated params: (0.01, 7, 100, 0.8, 1.0, 0.2) | MAE: 664.1796
# Evaluated params: (0.01, 7, 100, 1.0, 0.6, 0) | MAE: 622.9483
# Evaluated params: (0.01, 7, 100, 1.0, 0.6, 0.1) | MAE: 622.9483
# Evaluated params: (0.01, 7, 100, 1.0, 0.6, 0.2) | MAE: 622.9483
# Evaluated params: (0.01, 7, 100, 1.0, 0.8, 0) | MAE: 682.9091
# Evaluated params: (0.01, 7, 100, 1.0, 0.8, 0.1) | MAE: 682.9091
# Evaluated params: (0.01, 7, 100, 1.0, 0.8, 0.2) | MAE: 682.9091
# Evaluated params: (0.01, 7, 100, 1.0, 1.0, 0) | MAE: 689.0881
# Evaluated params: (0.01, 7, 100, 1.0, 1.0, 0.1) | MAE: 689.0881
# Evaluated params: (0.01, 7, 100, 1.0, 1.0, 0.2) | MAE: 689.0881
# Evaluated params: (0.01, 7, 150, 0.6, 0.6, 0) | MAE: 608.4358
# Evaluated params: (0.01, 7, 150, 0.6, 0.6, 0.1) | MAE: 608.4358
# Evaluated params: (0.01, 7, 150, 0.6, 0.6, 0.2) | MAE: 608.4358
# Evaluated params: (0.01, 7, 150, 0.6, 0.8, 0) | MAE: 608.9794
# Evaluated params: (0.01, 7, 150, 0.6, 0.8, 0.1) | MAE: 608.9794
# Evaluated params: (0.01, 7, 150, 0.6, 0.8, 0.2) | MAE: 608.9794
# Evaluated params: (0.01, 7, 150, 0.6, 1.0, 0) | MAE: 612.3160
# Evaluated params: (0.01, 7, 150, 0.6, 1.0, 0.1) | MAE: 612.3160
# Evaluated params: (0.01, 7, 150, 0.6, 1.0, 0.2) | MAE: 612.3160
# Evaluated params: (0.01, 7, 150, 0.8, 0.6, 0) | MAE: 643.4711
# Evaluated params: (0.01, 7, 150, 0.8, 0.6, 0.1) | MAE: 643.4711
# Evaluated params: (0.01, 7, 150, 0.8, 0.6, 0.2) | MAE: 643.4711
# Evaluated params: (0.01, 7, 150, 0.8, 0.8, 0) | MAE: 669.4587
# Evaluated params: (0.01, 7, 150, 0.8, 0.8, 0.1) | MAE: 669.4587
# Evaluated params: (0.01, 7, 150, 0.8, 0.8, 0.2) | MAE: 669.4587
# Evaluated params: (0.01, 7, 150, 0.8, 1.0, 0) | MAE: 670.9444
# Evaluated params: (0.01, 7, 150, 0.8, 1.0, 0.1) | MAE: 670.9444
# Evaluated params: (0.01, 7, 150, 0.8, 1.0, 0.2) | MAE: 670.9444
# Evaluated params: (0.01, 7, 150, 1.0, 0.6, 0) | MAE: 647.1256
# Evaluated params: (0.01, 7, 150, 1.0, 0.6, 0.1) | MAE: 647.1256
# Evaluated params: (0.01, 7, 150, 1.0, 0.6, 0.2) | MAE: 647.1256
# Evaluated params: (0.01, 7, 150, 1.0, 0.8, 0) | MAE: 698.8339
# Evaluated params: (0.01, 7, 150, 1.0, 0.8, 0.1) | MAE: 698.8339
# Evaluated params: (0.01, 7, 150, 1.0, 0.8, 0.2) | MAE: 698.8339
# Evaluated params: (0.01, 7, 150, 1.0, 1.0, 0) | MAE: 717.1287
# Evaluated params: (0.01, 7, 150, 1.0, 1.0, 0.1) | MAE: 717.1287
# Evaluated params: (0.01, 7, 150, 1.0, 1.0, 0.2) | MAE: 717.1287
# Evaluated params: (0.1, 3, 50, 0.6, 0.6, 0) | MAE: 850.5857
# Evaluated params: (0.1, 3, 50, 0.6, 0.6, 0.1) | MAE: 850.5857
# Evaluated params: (0.1, 3, 50, 0.6, 0.6, 0.2) | MAE: 850.5857
# Evaluated params: (0.1, 3, 50, 0.6, 0.8, 0) | MAE: 861.2976
# Evaluated params: (0.1, 3, 50, 0.6, 0.8, 0.1) | MAE: 861.2976
# Evaluated params: (0.1, 3, 50, 0.6, 0.8, 0.2) | MAE: 861.2976
# Evaluated params: (0.1, 3, 50, 0.6, 1.0, 0) | MAE: 833.5830
# Evaluated params: (0.1, 3, 50, 0.6, 1.0, 0.1) | MAE: 833.5830
# Evaluated params: (0.1, 3, 50, 0.6, 1.0, 0.2) | MAE: 833.5830
# Evaluated params: (0.1, 3, 50, 0.8, 0.6, 0) | MAE: 910.2531
# Evaluated params: (0.1, 3, 50, 0.8, 0.6, 0.1) | MAE: 910.2531
# Evaluated params: (0.1, 3, 50, 0.8, 0.6, 0.2) | MAE: 910.2531
# Evaluated params: (0.1, 3, 50, 0.8, 0.8, 0) | MAE: 868.0678
# Evaluated params: (0.1, 3, 50, 0.8, 0.8, 0.1) | MAE: 868.0678
# Evaluated params: (0.1, 3, 50, 0.8, 0.8, 0.2) | MAE: 868.0678
# Evaluated params: (0.1, 3, 50, 0.8, 1.0, 0) | MAE: 840.3171
# Evaluated params: (0.1, 3, 50, 0.8, 1.0, 0.1) | MAE: 840.3171
# Evaluated params: (0.1, 3, 50, 0.8, 1.0, 0.2) | MAE: 840.3171
# Evaluated params: (0.1, 3, 50, 1.0, 0.6, 0) | MAE: 948.3928
# Evaluated params: (0.1, 3, 50, 1.0, 0.6, 0.1) | MAE: 948.3928
# Evaluated params: (0.1, 3, 50, 1.0, 0.6, 0.2) | MAE: 948.3928
# Evaluated params: (0.1, 3, 50, 1.0, 0.8, 0) | MAE: 889.4371
# Evaluated params: (0.1, 3, 50, 1.0, 0.8, 0.1) | MAE: 889.4371
# Evaluated params: (0.1, 3, 50, 1.0, 0.8, 0.2) | MAE: 889.4371
# Evaluated params: (0.1, 3, 50, 1.0, 1.0, 0) | MAE: 884.6905
# Evaluated params: (0.1, 3, 50, 1.0, 1.0, 0.1) | MAE: 884.6905
# Evaluated params: (0.1, 3, 50, 1.0, 1.0, 0.2) | MAE: 884.6905
# Evaluated params: (0.1, 3, 100, 0.6, 0.6, 0) | MAE: 866.2217
# Evaluated params: (0.1, 3, 100, 0.6, 0.6, 0.1) | MAE: 866.2217
# Evaluated params: (0.1, 3, 100, 0.6, 0.6, 0.2) | MAE: 866.2217
# Evaluated params: (0.1, 3, 100, 0.6, 0.8, 0) | MAE: 880.3702
# Evaluated params: (0.1, 3, 100, 0.6, 0.8, 0.1) | MAE: 880.3702
# Evaluated params: (0.1, 3, 100, 0.6, 0.8, 0.2) | MAE: 880.3702
# Evaluated params: (0.1, 3, 100, 0.6, 1.0, 0) | MAE: 846.1583
# Evaluated params: (0.1, 3, 100, 0.6, 1.0, 0.1) | MAE: 846.1583
# Evaluated params: (0.1, 3, 100, 0.6, 1.0, 0.2) | MAE: 846.1583
# Evaluated params: (0.1, 3, 100, 0.8, 0.6, 0) | MAE: 907.5681
# Evaluated params: (0.1, 3, 100, 0.8, 0.6, 0.1) | MAE: 907.5681
# Evaluated params: (0.1, 3, 100, 0.8, 0.6, 0.2) | MAE: 907.5681
# Evaluated params: (0.1, 3, 100, 0.8, 0.8, 0) | MAE: 894.5776
# Evaluated params: (0.1, 3, 100, 0.8, 0.8, 0.1) | MAE: 894.5776
# Evaluated params: (0.1, 3, 100, 0.8, 0.8, 0.2) | MAE: 894.5776
# Evaluated params: (0.1, 3, 100, 0.8, 1.0, 0) | MAE: 866.6293
# Evaluated params: (0.1, 3, 100, 0.8, 1.0, 0.1) | MAE: 866.6293
# Evaluated params: (0.1, 3, 100, 0.8, 1.0, 0.2) | MAE: 866.6293
# Evaluated params: (0.1, 3, 100, 1.0, 0.6, 0) | MAE: 940.5386
# Evaluated params: (0.1, 3, 100, 1.0, 0.6, 0.1) | MAE: 940.5386
# Evaluated params: (0.1, 3, 100, 1.0, 0.6, 0.2) | MAE: 940.5386
# Evaluated params: (0.1, 3, 100, 1.0, 0.8, 0) | MAE: 908.0502
# Evaluated params: (0.1, 3, 100, 1.0, 0.8, 0.1) | MAE: 908.0502
# Evaluated params: (0.1, 3, 100, 1.0, 0.8, 0.2) | MAE: 908.0502
# Evaluated params: (0.1, 3, 100, 1.0, 1.0, 0) | MAE: 888.6361
# Evaluated params: (0.1, 3, 100, 1.0, 1.0, 0.1) | MAE: 888.6361
# Evaluated params: (0.1, 3, 100, 1.0, 1.0, 0.2) | MAE: 888.6361
# Evaluated params: (0.1, 3, 150, 0.6, 0.6, 0) | MAE: 846.5863
# Evaluated params: (0.1, 3, 150, 0.6, 0.6, 0.1) | MAE: 846.5863
# Evaluated params: (0.1, 3, 150, 0.6, 0.6, 0.2) | MAE: 846.5863
# Evaluated params: (0.1, 3, 150, 0.6, 0.8, 0) | MAE: 872.9365
# Evaluated params: (0.1, 3, 150, 0.6, 0.8, 0.1) | MAE: 872.9365
# Evaluated params: (0.1, 3, 150, 0.6, 0.8, 0.2) | MAE: 872.9365
# Evaluated params: (0.1, 3, 150, 0.6, 1.0, 0) | MAE: 838.0497
# Evaluated params: (0.1, 3, 150, 0.6, 1.0, 0.1) | MAE: 838.0497
# Evaluated params: (0.1, 3, 150, 0.6, 1.0, 0.2) | MAE: 838.0497
# Evaluated params: (0.1, 3, 150, 0.8, 0.6, 0) | MAE: 913.2144
# Evaluated params: (0.1, 3, 150, 0.8, 0.6, 0.1) | MAE: 913.2144
# Evaluated params: (0.1, 3, 150, 0.8, 0.6, 0.2) | MAE: 913.2144
# Evaluated params: (0.1, 3, 150, 0.8, 0.8, 0) | MAE: 897.5149
# Evaluated params: (0.1, 3, 150, 0.8, 0.8, 0.1) | MAE: 897.5149
# Evaluated params: (0.1, 3, 150, 0.8, 0.8, 0.2) | MAE: 897.5149
# Evaluated params: (0.1, 3, 150, 0.8, 1.0, 0) | MAE: 874.4399
# Evaluated params: (0.1, 3, 150, 0.8, 1.0, 0.1) | MAE: 874.4399
# Evaluated params: (0.1, 3, 150, 0.8, 1.0, 0.2) | MAE: 874.4399
# Evaluated params: (0.1, 3, 150, 1.0, 0.6, 0) | MAE: 939.8540
# Evaluated params: (0.1, 3, 150, 1.0, 0.6, 0.1) | MAE: 939.8540
# Evaluated params: (0.1, 3, 150, 1.0, 0.6, 0.2) | MAE: 939.8540
# Evaluated params: (0.1, 3, 150, 1.0, 0.8, 0) | MAE: 916.6410
# Evaluated params: (0.1, 3, 150, 1.0, 0.8, 0.1) | MAE: 916.6410
# Evaluated params: (0.1, 3, 150, 1.0, 0.8, 0.2) | MAE: 916.6410
# Evaluated params: (0.1, 3, 150, 1.0, 1.0, 0) | MAE: 901.9188
# Evaluated params: (0.1, 3, 150, 1.0, 1.0, 0.1) | MAE: 901.9188
# Evaluated params: (0.1, 3, 150, 1.0, 1.0, 0.2) | MAE: 901.9188
# Evaluated params: (0.1, 5, 50, 0.6, 0.6, 0) | MAE: 924.6109
# Evaluated params: (0.1, 5, 50, 0.6, 0.6, 0.1) | MAE: 924.6109
# Evaluated params: (0.1, 5, 50, 0.6, 0.6, 0.2) | MAE: 924.6109
# Evaluated params: (0.1, 5, 50, 0.6, 0.8, 0) | MAE: 740.7359
# Evaluated params: (0.1, 5, 50, 0.6, 0.8, 0.1) | MAE: 740.7359
# Evaluated params: (0.1, 5, 50, 0.6, 0.8, 0.2) | MAE: 740.7359
# Evaluated params: (0.1, 5, 50, 0.6, 1.0, 0) | MAE: 907.3701
# Evaluated params: (0.1, 5, 50, 0.6, 1.0, 0.1) | MAE: 907.3701
# Evaluated params: (0.1, 5, 50, 0.6, 1.0, 0.2) | MAE: 907.3701
# Evaluated params: (0.1, 5, 50, 0.8, 0.6, 0) | MAE: 845.5660
# Evaluated params: (0.1, 5, 50, 0.8, 0.6, 0.1) | MAE: 845.5660
# Evaluated params: (0.1, 5, 50, 0.8, 0.6, 0.2) | MAE: 845.5660
# Evaluated params: (0.1, 5, 50, 0.8, 0.8, 0) | MAE: 851.1809
# Evaluated params: (0.1, 5, 50, 0.8, 0.8, 0.1) | MAE: 851.1809
# Evaluated params: (0.1, 5, 50, 0.8, 0.8, 0.2) | MAE: 851.1809
# Evaluated params: (0.1, 5, 50, 0.8, 1.0, 0) | MAE: 894.7927
# Evaluated params: (0.1, 5, 50, 0.8, 1.0, 0.1) | MAE: 894.7927
# Evaluated params: (0.1, 5, 50, 0.8, 1.0, 0.2) | MAE: 894.7927
# Evaluated params: (0.1, 5, 50, 1.0, 0.6, 0) | MAE: 819.4720
# Evaluated params: (0.1, 5, 50, 1.0, 0.6, 0.1) | MAE: 819.4720
# Evaluated params: (0.1, 5, 50, 1.0, 0.6, 0.2) | MAE: 819.4720
# Evaluated params: (0.1, 5, 50, 1.0, 0.8, 0) | MAE: 1007.1113
# Evaluated params: (0.1, 5, 50, 1.0, 0.8, 0.1) | MAE: 1007.1113
# Evaluated params: (0.1, 5, 50, 1.0, 0.8, 0.2) | MAE: 1007.1113
# Evaluated params: (0.1, 5, 50, 1.0, 1.0, 0) | MAE: 886.9040
# Evaluated params: (0.1, 5, 50, 1.0, 1.0, 0.1) | MAE: 886.9040
# Evaluated params: (0.1, 5, 50, 1.0, 1.0, 0.2) | MAE: 886.9040
# Evaluated params: (0.1, 5, 100, 0.6, 0.6, 0) | MAE: 935.2172
# Evaluated params: (0.1, 5, 100, 0.6, 0.6, 0.1) | MAE: 935.2172
# Evaluated params: (0.1, 5, 100, 0.6, 0.6, 0.2) | MAE: 935.2172
# Evaluated params: (0.1, 5, 100, 0.6, 0.8, 0) | MAE: 757.1019
# Evaluated params: (0.1, 5, 100, 0.6, 0.8, 0.1) | MAE: 757.1019
# Evaluated params: (0.1, 5, 100, 0.6, 0.8, 0.2) | MAE: 757.1019
# Evaluated params: (0.1, 5, 100, 0.6, 1.0, 0) | MAE: 927.3914
# Evaluated params: (0.1, 5, 100, 0.6, 1.0, 0.1) | MAE: 927.3914
# Evaluated params: (0.1, 5, 100, 0.6, 1.0, 0.2) | MAE: 927.3914
# Evaluated params: (0.1, 5, 100, 0.8, 0.6, 0) | MAE: 865.8159
# Evaluated params: (0.1, 5, 100, 0.8, 0.6, 0.1) | MAE: 865.8159
# Evaluated params: (0.1, 5, 100, 0.8, 0.6, 0.2) | MAE: 865.8159
# Evaluated params: (0.1, 5, 100, 0.8, 0.8, 0) | MAE: 858.2388
# Evaluated params: (0.1, 5, 100, 0.8, 0.8, 0.1) | MAE: 858.2388
# Evaluated params: (0.1, 5, 100, 0.8, 0.8, 0.2) | MAE: 858.2388
# Evaluated params: (0.1, 5, 100, 0.8, 1.0, 0) | MAE: 917.0861
# Evaluated params: (0.1, 5, 100, 0.8, 1.0, 0.1) | MAE: 917.0861
# Evaluated params: (0.1, 5, 100, 0.8, 1.0, 0.2) | MAE: 917.0861
# Evaluated params: (0.1, 5, 100, 1.0, 0.6, 0) | MAE: 835.0933
# Evaluated params: (0.1, 5, 100, 1.0, 0.6, 0.1) | MAE: 835.0933
# Evaluated params: (0.1, 5, 100, 1.0, 0.6, 0.2) | MAE: 835.0933
# Evaluated params: (0.1, 5, 100, 1.0, 0.8, 0) | MAE: 1019.2641
# Evaluated params: (0.1, 5, 100, 1.0, 0.8, 0.1) | MAE: 1019.2641
# Evaluated params: (0.1, 5, 100, 1.0, 0.8, 0.2) | MAE: 1019.2641
# Evaluated params: (0.1, 5, 100, 1.0, 1.0, 0) | MAE: 898.3350
# Evaluated params: (0.1, 5, 100, 1.0, 1.0, 0.1) | MAE: 898.3350
# Evaluated params: (0.1, 5, 100, 1.0, 1.0, 0.2) | MAE: 898.3350
# Evaluated params: (0.1, 5, 150, 0.6, 0.6, 0) | MAE: 947.6298
# Evaluated params: (0.1, 5, 150, 0.6, 0.6, 0.1) | MAE: 947.6298
# Evaluated params: (0.1, 5, 150, 0.6, 0.6, 0.2) | MAE: 947.6298
# Evaluated params: (0.1, 5, 150, 0.6, 0.8, 0) | MAE: 763.1372
# Evaluated params: (0.1, 5, 150, 0.6, 0.8, 0.1) | MAE: 763.1372
# Evaluated params: (0.1, 5, 150, 0.6, 0.8, 0.2) | MAE: 763.1372
# Evaluated params: (0.1, 5, 150, 0.6, 1.0, 0) | MAE: 937.7549
# Evaluated params: (0.1, 5, 150, 0.6, 1.0, 0.1) | MAE: 937.7549
# Evaluated params: (0.1, 5, 150, 0.6, 1.0, 0.2) | MAE: 937.7549
# Evaluated params: (0.1, 5, 150, 0.8, 0.6, 0) | MAE: 872.7843
# Evaluated params: (0.1, 5, 150, 0.8, 0.6, 0.1) | MAE: 872.7843
# Evaluated params: (0.1, 5, 150, 0.8, 0.6, 0.2) | MAE: 872.7843
# Evaluated params: (0.1, 5, 150, 0.8, 0.8, 0) | MAE: 866.3303
# Evaluated params: (0.1, 5, 150, 0.8, 0.8, 0.1) | MAE: 866.3303
# Evaluated params: (0.1, 5, 150, 0.8, 0.8, 0.2) | MAE: 866.3303
# Evaluated params: (0.1, 5, 150, 0.8, 1.0, 0) | MAE: 931.0334
# Evaluated params: (0.1, 5, 150, 0.8, 1.0, 0.1) | MAE: 931.0334
# Evaluated params: (0.1, 5, 150, 0.8, 1.0, 0.2) | MAE: 931.0334
# Evaluated params: (0.1, 5, 150, 1.0, 0.6, 0) | MAE: 837.3809
# Evaluated params: (0.1, 5, 150, 1.0, 0.6, 0.1) | MAE: 837.3809
# Evaluated params: (0.1, 5, 150, 1.0, 0.6, 0.2) | MAE: 837.3809
# Evaluated params: (0.1, 5, 150, 1.0, 0.8, 0) | MAE: 1030.9322
# Evaluated params: (0.1, 5, 150, 1.0, 0.8, 0.1) | MAE: 1030.9322
# Evaluated params: (0.1, 5, 150, 1.0, 0.8, 0.2) | MAE: 1030.9322
# Evaluated params: (0.1, 5, 150, 1.0, 1.0, 0) | MAE: 901.8851
# Evaluated params: (0.1, 5, 150, 1.0, 1.0, 0.1) | MAE: 901.8851
# Evaluated params: (0.1, 5, 150, 1.0, 1.0, 0.2) | MAE: 901.8851
# Evaluated params: (0.1, 7, 50, 0.6, 0.6, 0) | MAE: 865.4776
# Evaluated params: (0.1, 7, 50, 0.6, 0.6, 0.1) | MAE: 865.4776
# Evaluated params: (0.1, 7, 50, 0.6, 0.6, 0.2) | MAE: 865.4776
# Evaluated params: (0.1, 7, 50, 0.6, 0.8, 0) | MAE: 881.0718
# Evaluated params: (0.1, 7, 50, 0.6, 0.8, 0.1) | MAE: 881.0718
# Evaluated params: (0.1, 7, 50, 0.6, 0.8, 0.2) | MAE: 881.0718
# Evaluated params: (0.1, 7, 50, 0.6, 1.0, 0) | MAE: 876.0266
# Evaluated params: (0.1, 7, 50, 0.6, 1.0, 0.1) | MAE: 876.0266
# Evaluated params: (0.1, 7, 50, 0.6, 1.0, 0.2) | MAE: 876.0266
# Evaluated params: (0.1, 7, 50, 0.8, 0.6, 0) | MAE: 829.1232
# Evaluated params: (0.1, 7, 50, 0.8, 0.6, 0.1) | MAE: 829.1232
# Evaluated params: (0.1, 7, 50, 0.8, 0.6, 0.2) | MAE: 829.1232
# Evaluated params: (0.1, 7, 50, 0.8, 0.8, 0) | MAE: 900.7859
# Evaluated params: (0.1, 7, 50, 0.8, 0.8, 0.1) | MAE: 900.7859
# Evaluated params: (0.1, 7, 50, 0.8, 0.8, 0.2) | MAE: 900.7859
# Evaluated params: (0.1, 7, 50, 0.8, 1.0, 0) | MAE: 918.5206
# Evaluated params: (0.1, 7, 50, 0.8, 1.0, 0.1) | MAE: 918.5206
# Evaluated params: (0.1, 7, 50, 0.8, 1.0, 0.2) | MAE: 918.5206
# Evaluated params: (0.1, 7, 50, 1.0, 0.6, 0) | MAE: 950.5674
# Evaluated params: (0.1, 7, 50, 1.0, 0.6, 0.1) | MAE: 950.5674
# Evaluated params: (0.1, 7, 50, 1.0, 0.6, 0.2) | MAE: 950.5674
# Evaluated params: (0.1, 7, 50, 1.0, 0.8, 0) | MAE: 999.4210
# Evaluated params: (0.1, 7, 50, 1.0, 0.8, 0.1) | MAE: 999.4210
# Evaluated params: (0.1, 7, 50, 1.0, 0.8, 0.2) | MAE: 999.4210
# Evaluated params: (0.1, 7, 50, 1.0, 1.0, 0) | MAE: 932.1318
# Evaluated params: (0.1, 7, 50, 1.0, 1.0, 0.1) | MAE: 932.1318
# Evaluated params: (0.1, 7, 50, 1.0, 1.0, 0.2) | MAE: 932.1318
# Evaluated params: (0.1, 7, 100, 0.6, 0.6, 0) | MAE: 881.8771
# Evaluated params: (0.1, 7, 100, 0.6, 0.6, 0.1) | MAE: 881.8771
# Evaluated params: (0.1, 7, 100, 0.6, 0.6, 0.2) | MAE: 881.8771
# Evaluated params: (0.1, 7, 100, 0.6, 0.8, 0) | MAE: 888.4697
# Evaluated params: (0.1, 7, 100, 0.6, 0.8, 0.1) | MAE: 888.4697
# Evaluated params: (0.1, 7, 100, 0.6, 0.8, 0.2) | MAE: 888.4697
# Evaluated params: (0.1, 7, 100, 0.6, 1.0, 0) | MAE: 888.9370
# Evaluated params: (0.1, 7, 100, 0.6, 1.0, 0.1) | MAE: 888.9370
# Evaluated params: (0.1, 7, 100, 0.6, 1.0, 0.2) | MAE: 888.9370
# Evaluated params: (0.1, 7, 100, 0.8, 0.6, 0) | MAE: 843.1103
# Evaluated params: (0.1, 7, 100, 0.8, 0.6, 0.1) | MAE: 843.1103
# Evaluated params: (0.1, 7, 100, 0.8, 0.6, 0.2) | MAE: 843.1103
# Evaluated params: (0.1, 7, 100, 0.8, 0.8, 0) | MAE: 917.8249
# Evaluated params: (0.1, 7, 100, 0.8, 0.8, 0.1) | MAE: 917.8249
# Evaluated params: (0.1, 7, 100, 0.8, 0.8, 0.2) | MAE: 917.8249
# Evaluated params: (0.1, 7, 100, 0.8, 1.0, 0) | MAE: 923.8116
# Evaluated params: (0.1, 7, 100, 0.8, 1.0, 0.1) | MAE: 923.8116
# Evaluated params: (0.1, 7, 100, 0.8, 1.0, 0.2) | MAE: 923.8116
# Evaluated params: (0.1, 7, 100, 1.0, 0.6, 0) | MAE: 960.1205
# Evaluated params: (0.1, 7, 100, 1.0, 0.6, 0.1) | MAE: 960.1205
# Evaluated params: (0.1, 7, 100, 1.0, 0.6, 0.2) | MAE: 960.1205
# Evaluated params: (0.1, 7, 100, 1.0, 0.8, 0) | MAE: 1015.8207
# Evaluated params: (0.1, 7, 100, 1.0, 0.8, 0.1) | MAE: 1015.8207
# Evaluated params: (0.1, 7, 100, 1.0, 0.8, 0.2) | MAE: 1015.8207
# Evaluated params: (0.1, 7, 100, 1.0, 1.0, 0) | MAE: 942.8453
# Evaluated params: (0.1, 7, 100, 1.0, 1.0, 0.1) | MAE: 942.8453
# Evaluated params: (0.1, 7, 100, 1.0, 1.0, 0.2) | MAE: 942.8453
# Evaluated params: (0.1, 7, 150, 0.6, 0.6, 0) | MAE: 888.8580
# Evaluated params: (0.1, 7, 150, 0.6, 0.6, 0.1) | MAE: 888.8580
# Evaluated params: (0.1, 7, 150, 0.6, 0.6, 0.2) | MAE: 888.8580
# Evaluated params: (0.1, 7, 150, 0.6, 0.8, 0) | MAE: 895.3570
# Evaluated params: (0.1, 7, 150, 0.6, 0.8, 0.1) | MAE: 895.3570
# Evaluated params: (0.1, 7, 150, 0.6, 0.8, 0.2) | MAE: 895.3570
# Evaluated params: (0.1, 7, 150, 0.6, 1.0, 0) | MAE: 906.1118
# Evaluated params: (0.1, 7, 150, 0.6, 1.0, 0.1) | MAE: 906.1118
# Evaluated params: (0.1, 7, 150, 0.6, 1.0, 0.2) | MAE: 906.1117
# Evaluated params: (0.1, 7, 150, 0.8, 0.6, 0) | MAE: 839.1392
# Evaluated params: (0.1, 7, 150, 0.8, 0.6, 0.1) | MAE: 839.1392
# Evaluated params: (0.1, 7, 150, 0.8, 0.6, 0.2) | MAE: 839.1392
# Evaluated params: (0.1, 7, 150, 0.8, 0.8, 0) | MAE: 926.6553
# Evaluated params: (0.1, 7, 150, 0.8, 0.8, 0.1) | MAE: 926.6553
# Evaluated params: (0.1, 7, 150, 0.8, 0.8, 0.2) | MAE: 926.6553
# Evaluated params: (0.1, 7, 150, 0.8, 1.0, 0) | MAE: 927.4685
# Evaluated params: (0.1, 7, 150, 0.8, 1.0, 0.1) | MAE: 927.4685
# Evaluated params: (0.1, 7, 150, 0.8, 1.0, 0.2) | MAE: 927.4685
# Evaluated params: (0.1, 7, 150, 1.0, 0.6, 0) | MAE: 963.7611
# Evaluated params: (0.1, 7, 150, 1.0, 0.6, 0.1) | MAE: 963.7611
# Evaluated params: (0.1, 7, 150, 1.0, 0.6, 0.2) | MAE: 963.7611
# Evaluated params: (0.1, 7, 150, 1.0, 0.8, 0) | MAE: 1019.9652
# Evaluated params: (0.1, 7, 150, 1.0, 0.8, 0.1) | MAE: 1019.9652
# Evaluated params: (0.1, 7, 150, 1.0, 0.8, 0.2) | MAE: 1019.9652
# Evaluated params: (0.1, 7, 150, 1.0, 1.0, 0) | MAE: 949.7952
# Evaluated params: (0.1, 7, 150, 1.0, 1.0, 0.1) | MAE: 949.7952
# Evaluated params: (0.1, 7, 150, 1.0, 1.0, 0.2) | MAE: 949.7952
# Evaluated params: (0.2, 3, 50, 0.6, 0.6, 0) | MAE: 839.9413
# Evaluated params: (0.2, 3, 50, 0.6, 0.6, 0.1) | MAE: 839.9413
# Evaluated params: (0.2, 3, 50, 0.6, 0.6, 0.2) | MAE: 839.9413
# Evaluated params: (0.2, 3, 50, 0.6, 0.8, 0) | MAE: 834.2023
# Evaluated params: (0.2, 3, 50, 0.6, 0.8, 0.1) | MAE: 834.2023
# Evaluated params: (0.2, 3, 50, 0.6, 0.8, 0.2) | MAE: 834.2023
# Evaluated params: (0.2, 3, 50, 0.6, 1.0, 0) | MAE: 761.0670
# Evaluated params: (0.2, 3, 50, 0.6, 1.0, 0.1) | MAE: 761.0670
# Evaluated params: (0.2, 3, 50, 0.6, 1.0, 0.2) | MAE: 761.0670
# Evaluated params: (0.2, 3, 50, 0.8, 0.6, 0) | MAE: 907.4964
# Evaluated params: (0.2, 3, 50, 0.8, 0.6, 0.1) | MAE: 907.4964
# Evaluated params: (0.2, 3, 50, 0.8, 0.6, 0.2) | MAE: 907.4964
# Evaluated params: (0.2, 3, 50, 0.8, 0.8, 0) | MAE: 914.8996
# Evaluated params: (0.2, 3, 50, 0.8, 0.8, 0.1) | MAE: 914.8996
# Evaluated params: (0.2, 3, 50, 0.8, 0.8, 0.2) | MAE: 914.8996
# Evaluated params: (0.2, 3, 50, 0.8, 1.0, 0) | MAE: 879.3183
# Evaluated params: (0.2, 3, 50, 0.8, 1.0, 0.1) | MAE: 879.3183
# Evaluated params: (0.2, 3, 50, 0.8, 1.0, 0.2) | MAE: 879.3183
# Evaluated params: (0.2, 3, 50, 1.0, 0.6, 0) | MAE: 953.5578
# Evaluated params: (0.2, 3, 50, 1.0, 0.6, 0.1) | MAE: 953.5578
# Evaluated params: (0.2, 3, 50, 1.0, 0.6, 0.2) | MAE: 953.5578
# Evaluated params: (0.2, 3, 50, 1.0, 0.8, 0) | MAE: 917.5483
# Evaluated params: (0.2, 3, 50, 1.0, 0.8, 0.1) | MAE: 917.5483
# Evaluated params: (0.2, 3, 50, 1.0, 0.8, 0.2) | MAE: 917.5483
# Evaluated params: (0.2, 3, 50, 1.0, 1.0, 0) | MAE: 840.3869
# Evaluated params: (0.2, 3, 50, 1.0, 1.0, 0.1) | MAE: 840.3869
# Evaluated params: (0.2, 3, 50, 1.0, 1.0, 0.2) | MAE: 840.3869
# Evaluated params: (0.2, 3, 100, 0.6, 0.6, 0) | MAE: 826.9361
# Evaluated params: (0.2, 3, 100, 0.6, 0.6, 0.1) | MAE: 826.9361
# Evaluated params: (0.2, 3, 100, 0.6, 0.6, 0.2) | MAE: 826.9361
# Evaluated params: (0.2, 3, 100, 0.6, 0.8, 0) | MAE: 838.9849
# Evaluated params: (0.2, 3, 100, 0.6, 0.8, 0.1) | MAE: 838.9849
# Evaluated params: (0.2, 3, 100, 0.6, 0.8, 0.2) | MAE: 838.9849
# Evaluated params: (0.2, 3, 100, 0.6, 1.0, 0) | MAE: 777.0092
# Evaluated params: (0.2, 3, 100, 0.6, 1.0, 0.1) | MAE: 777.0092
# Evaluated params: (0.2, 3, 100, 0.6, 1.0, 0.2) | MAE: 777.0092
# Evaluated params: (0.2, 3, 100, 0.8, 0.6, 0) | MAE: 901.9943
# Evaluated params: (0.2, 3, 100, 0.8, 0.6, 0.1) | MAE: 901.9943
# Evaluated params: (0.2, 3, 100, 0.8, 0.6, 0.2) | MAE: 901.9943
# Evaluated params: (0.2, 3, 100, 0.8, 0.8, 0) | MAE: 925.5726
# Evaluated params: (0.2, 3, 100, 0.8, 0.8, 0.1) | MAE: 925.5726
# Evaluated params: (0.2, 3, 100, 0.8, 0.8, 0.2) | MAE: 925.5726
# Evaluated params: (0.2, 3, 100, 0.8, 1.0, 0) | MAE: 882.6237
# Evaluated params: (0.2, 3, 100, 0.8, 1.0, 0.1) | MAE: 882.6237
# Evaluated params: (0.2, 3, 100, 0.8, 1.0, 0.2) | MAE: 882.6237
# Evaluated params: (0.2, 3, 100, 1.0, 0.6, 0) | MAE: 979.2245
# Evaluated params: (0.2, 3, 100, 1.0, 0.6, 0.1) | MAE: 979.2245
# Evaluated params: (0.2, 3, 100, 1.0, 0.6, 0.2) | MAE: 979.2245
# Evaluated params: (0.2, 3, 100, 1.0, 0.8, 0) | MAE: 933.6931
# Evaluated params: (0.2, 3, 100, 1.0, 0.8, 0.1) | MAE: 933.6931
# Evaluated params: (0.2, 3, 100, 1.0, 0.8, 0.2) | MAE: 933.6931
# Evaluated params: (0.2, 3, 100, 1.0, 1.0, 0) | MAE: 839.6975
# Evaluated params: (0.2, 3, 100, 1.0, 1.0, 0.1) | MAE: 839.6975
# Evaluated params: (0.2, 3, 100, 1.0, 1.0, 0.2) | MAE: 839.6975
# Evaluated params: (0.2, 3, 150, 0.6, 0.6, 0) | MAE: 824.0339
# Evaluated params: (0.2, 3, 150, 0.6, 0.6, 0.1) | MAE: 824.0339
# Evaluated params: (0.2, 3, 150, 0.6, 0.6, 0.2) | MAE: 824.0339
# Evaluated params: (0.2, 3, 150, 0.6, 0.8, 0) | MAE: 849.4141
# Evaluated params: (0.2, 3, 150, 0.6, 0.8, 0.1) | MAE: 849.4141
# Evaluated params: (0.2, 3, 150, 0.6, 0.8, 0.2) | MAE: 849.4141
# Evaluated params: (0.2, 3, 150, 0.6, 1.0, 0) | MAE: 803.7143
# Evaluated params: (0.2, 3, 150, 0.6, 1.0, 0.1) | MAE: 803.7143
# Evaluated params: (0.2, 3, 150, 0.6, 1.0, 0.2) | MAE: 803.7143
# Evaluated params: (0.2, 3, 150, 0.8, 0.6, 0) | MAE: 928.3381
# Evaluated params: (0.2, 3, 150, 0.8, 0.6, 0.1) | MAE: 928.3381
# Evaluated params: (0.2, 3, 150, 0.8, 0.6, 0.2) | MAE: 928.3381
# Evaluated params: (0.2, 3, 150, 0.8, 0.8, 0) | MAE: 956.6371
# Evaluated params: (0.2, 3, 150, 0.8, 0.8, 0.1) | MAE: 956.6371
# Evaluated params: (0.2, 3, 150, 0.8, 0.8, 0.2) | MAE: 956.6371
# Evaluated params: (0.2, 3, 150, 0.8, 1.0, 0) | MAE: 896.8650
# Evaluated params: (0.2, 3, 150, 0.8, 1.0, 0.1) | MAE: 896.8650
# Evaluated params: (0.2, 3, 150, 0.8, 1.0, 0.2) | MAE: 896.8650
# Evaluated params: (0.2, 3, 150, 1.0, 0.6, 0) | MAE: 973.2817
# Evaluated params: (0.2, 3, 150, 1.0, 0.6, 0.1) | MAE: 973.2817
# Evaluated params: (0.2, 3, 150, 1.0, 0.6, 0.2) | MAE: 973.2817
# Evaluated params: (0.2, 3, 150, 1.0, 0.8, 0) | MAE: 934.8774
# Evaluated params: (0.2, 3, 150, 1.0, 0.8, 0.1) | MAE: 934.8774
# Evaluated params: (0.2, 3, 150, 1.0, 0.8, 0.2) | MAE: 934.8774
# Evaluated params: (0.2, 3, 150, 1.0, 1.0, 0) | MAE: 855.6537
# Evaluated params: (0.2, 3, 150, 1.0, 1.0, 0.1) | MAE: 855.6537
# Evaluated params: (0.2, 3, 150, 1.0, 1.0, 0.2) | MAE: 855.6537
# Evaluated params: (0.2, 5, 50, 0.6, 0.6, 0) | MAE: 800.5472
# Evaluated params: (0.2, 5, 50, 0.6, 0.6, 0.1) | MAE: 800.5472
# Evaluated params: (0.2, 5, 50, 0.6, 0.6, 0.2) | MAE: 800.5472
# Evaluated params: (0.2, 5, 50, 0.6, 0.8, 0) | MAE: 808.3870
# Evaluated params: (0.2, 5, 50, 0.6, 0.8, 0.1) | MAE: 808.3870
# Evaluated params: (0.2, 5, 50, 0.6, 0.8, 0.2) | MAE: 808.3870
# Evaluated params: (0.2, 5, 50, 0.6, 1.0, 0) | MAE: 924.5623
# Evaluated params: (0.2, 5, 50, 0.6, 1.0, 0.1) | MAE: 924.5623
# Evaluated params: (0.2, 5, 50, 0.6, 1.0, 0.2) | MAE: 924.5623
# Evaluated params: (0.2, 5, 50, 0.8, 0.6, 0) | MAE: 835.9495
# Evaluated params: (0.2, 5, 50, 0.8, 0.6, 0.1) | MAE: 835.9495
# Evaluated params: (0.2, 5, 50, 0.8, 0.6, 0.2) | MAE: 835.9495
# Evaluated params: (0.2, 5, 50, 0.8, 0.8, 0) | MAE: 912.5561
# Evaluated params: (0.2, 5, 50, 0.8, 0.8, 0.1) | MAE: 912.5561
# Evaluated params: (0.2, 5, 50, 0.8, 0.8, 0.2) | MAE: 912.5561
# Evaluated params: (0.2, 5, 50, 0.8, 1.0, 0) | MAE: 899.5149
# Evaluated params: (0.2, 5, 50, 0.8, 1.0, 0.1) | MAE: 899.5149
# Evaluated params: (0.2, 5, 50, 0.8, 1.0, 0.2) | MAE: 899.5149
# Evaluated params: (0.2, 5, 50, 1.0, 0.6, 0) | MAE: 828.4319
# Evaluated params: (0.2, 5, 50, 1.0, 0.6, 0.1) | MAE: 828.4319
# Evaluated params: (0.2, 5, 50, 1.0, 0.6, 0.2) | MAE: 828.4319
# Evaluated params: (0.2, 5, 50, 1.0, 0.8, 0) | MAE: 949.2388
# Evaluated params: (0.2, 5, 50, 1.0, 0.8, 0.1) | MAE: 949.2388
# Evaluated params: (0.2, 5, 50, 1.0, 0.8, 0.2) | MAE: 949.2388
# Evaluated params: (0.2, 5, 50, 1.0, 1.0, 0) | MAE: 1029.7595
# Evaluated params: (0.2, 5, 50, 1.0, 1.0, 0.1) | MAE: 1029.7595
# Evaluated params: (0.2, 5, 50, 1.0, 1.0, 0.2) | MAE: 1029.7595
# Evaluated params: (0.2, 5, 100, 0.6, 0.6, 0) | MAE: 821.5927
# Evaluated params: (0.2, 5, 100, 0.6, 0.6, 0.1) | MAE: 821.5927
# Evaluated params: (0.2, 5, 100, 0.6, 0.6, 0.2) | MAE: 821.5927
# Evaluated params: (0.2, 5, 100, 0.6, 0.8, 0) | MAE: 827.2548
# Evaluated params: (0.2, 5, 100, 0.6, 0.8, 0.1) | MAE: 827.2548
# Evaluated params: (0.2, 5, 100, 0.6, 0.8, 0.2) | MAE: 827.2548
# Evaluated params: (0.2, 5, 100, 0.6, 1.0, 0) | MAE: 924.6016
# Evaluated params: (0.2, 5, 100, 0.6, 1.0, 0.1) | MAE: 924.6016
# Evaluated params: (0.2, 5, 100, 0.6, 1.0, 0.2) | MAE: 924.6016
# Evaluated params: (0.2, 5, 100, 0.8, 0.6, 0) | MAE: 866.6344
# Evaluated params: (0.2, 5, 100, 0.8, 0.6, 0.1) | MAE: 866.6344
# Evaluated params: (0.2, 5, 100, 0.8, 0.6, 0.2) | MAE: 866.6344
# Evaluated params: (0.2, 5, 100, 0.8, 0.8, 0) | MAE: 939.9104
# Evaluated params: (0.2, 5, 100, 0.8, 0.8, 0.1) | MAE: 939.9104
# Evaluated params: (0.2, 5, 100, 0.8, 0.8, 0.2) | MAE: 939.9104
# Evaluated params: (0.2, 5, 100, 0.8, 1.0, 0) | MAE: 912.3675
# Evaluated params: (0.2, 5, 100, 0.8, 1.0, 0.1) | MAE: 912.3675
# Evaluated params: (0.2, 5, 100, 0.8, 1.0, 0.2) | MAE: 912.3675
# Evaluated params: (0.2, 5, 100, 1.0, 0.6, 0) | MAE: 839.7095
# Evaluated params: (0.2, 5, 100, 1.0, 0.6, 0.1) | MAE: 839.7095
# Evaluated params: (0.2, 5, 100, 1.0, 0.6, 0.2) | MAE: 839.7095
# Evaluated params: (0.2, 5, 100, 1.0, 0.8, 0) | MAE: 969.5573
# Evaluated params: (0.2, 5, 100, 1.0, 0.8, 0.1) | MAE: 969.5573
# Evaluated params: (0.2, 5, 100, 1.0, 0.8, 0.2) | MAE: 969.5573
# Evaluated params: (0.2, 5, 100, 1.0, 1.0, 0) | MAE: 1042.2538
# Evaluated params: (0.2, 5, 100, 1.0, 1.0, 0.1) | MAE: 1042.2538
# Evaluated params: (0.2, 5, 100, 1.0, 1.0, 0.2) | MAE: 1042.2528
# Evaluated params: (0.2, 5, 150, 0.6, 0.6, 0) | MAE: 847.2452
# Evaluated params: (0.2, 5, 150, 0.6, 0.6, 0.1) | MAE: 847.2452
# Evaluated params: (0.2, 5, 150, 0.6, 0.6, 0.2) | MAE: 847.2452
# Evaluated params: (0.2, 5, 150, 0.6, 0.8, 0) | MAE: 847.2379
# Evaluated params: (0.2, 5, 150, 0.6, 0.8, 0.1) | MAE: 847.2379
# Evaluated params: (0.2, 5, 150, 0.6, 0.8, 0.2) | MAE: 847.2379
# Evaluated params: (0.2, 5, 150, 0.6, 1.0, 0) | MAE: 923.0184
# Evaluated params: (0.2, 5, 150, 0.6, 1.0, 0.1) | MAE: 923.0184
# Evaluated params: (0.2, 5, 150, 0.6, 1.0, 0.2) | MAE: 923.0184
# Evaluated params: (0.2, 5, 150, 0.8, 0.6, 0) | MAE: 878.1121
# Evaluated params: (0.2, 5, 150, 0.8, 0.6, 0.1) | MAE: 878.1121
# Evaluated params: (0.2, 5, 150, 0.8, 0.6, 0.2) | MAE: 878.1121
# Evaluated params: (0.2, 5, 150, 0.8, 0.8, 0) | MAE: 947.4074
# Evaluated params: (0.2, 5, 150, 0.8, 0.8, 0.1) | MAE: 947.4074
# Evaluated params: (0.2, 5, 150, 0.8, 0.8, 0.2) | MAE: 947.4074
# Evaluated params: (0.2, 5, 150, 0.8, 1.0, 0) | MAE: 920.2450
# Evaluated params: (0.2, 5, 150, 0.8, 1.0, 0.1) | MAE: 920.2450
# Evaluated params: (0.2, 5, 150, 0.8, 1.0, 0.2) | MAE: 920.2450
# Evaluated params: (0.2, 5, 150, 1.0, 0.6, 0) | MAE: 842.2336
# Evaluated params: (0.2, 5, 150, 1.0, 0.6, 0.1) | MAE: 842.2336
# Evaluated params: (0.2, 5, 150, 1.0, 0.6, 0.2) | MAE: 842.2336
# Evaluated params: (0.2, 5, 150, 1.0, 0.8, 0) | MAE: 961.6793
# Evaluated params: (0.2, 5, 150, 1.0, 0.8, 0.1) | MAE: 961.6793
# Evaluated params: (0.2, 5, 150, 1.0, 0.8, 0.2) | MAE: 961.6793
# Evaluated params: (0.2, 5, 150, 1.0, 1.0, 0) | MAE: 1054.0605
# Evaluated params: (0.2, 5, 150, 1.0, 1.0, 0.1) | MAE: 1054.0610
# Evaluated params: (0.2, 5, 150, 1.0, 1.0, 0.2) | MAE: 1048.7132
# Evaluated params: (0.2, 7, 50, 0.6, 0.6, 0) | MAE: 800.7161
# Evaluated params: (0.2, 7, 50, 0.6, 0.6, 0.1) | MAE: 800.7161
# Evaluated params: (0.2, 7, 50, 0.6, 0.6, 0.2) | MAE: 800.7161
# Evaluated params: (0.2, 7, 50, 0.6, 0.8, 0) | MAE: 834.5856
# Evaluated params: (0.2, 7, 50, 0.6, 0.8, 0.1) | MAE: 834.5856
# Evaluated params: (0.2, 7, 50, 0.6, 0.8, 0.2) | MAE: 834.5856
# Evaluated params: (0.2, 7, 50, 0.6, 1.0, 0) | MAE: 858.8114
# Evaluated params: (0.2, 7, 50, 0.6, 1.0, 0.1) | MAE: 858.8114
# Evaluated params: (0.2, 7, 50, 0.6, 1.0, 0.2) | MAE: 858.8114
# Evaluated params: (0.2, 7, 50, 0.8, 0.6, 0) | MAE: 774.8683
# Evaluated params: (0.2, 7, 50, 0.8, 0.6, 0.1) | MAE: 774.8683
# Evaluated params: (0.2, 7, 50, 0.8, 0.6, 0.2) | MAE: 774.8683
# Evaluated params: (0.2, 7, 50, 0.8, 0.8, 0) | MAE: 992.7749
# Evaluated params: (0.2, 7, 50, 0.8, 0.8, 0.1) | MAE: 992.7749
# Evaluated params: (0.2, 7, 50, 0.8, 0.8, 0.2) | MAE: 992.7749
# Evaluated params: (0.2, 7, 50, 0.8, 1.0, 0) | MAE: 887.2174
# Evaluated params: (0.2, 7, 50, 0.8, 1.0, 0.1) | MAE: 887.2174
# Evaluated params: (0.2, 7, 50, 0.8, 1.0, 0.2) | MAE: 887.2174
# Evaluated params: (0.2, 7, 50, 1.0, 0.6, 0) | MAE: 913.7480
# Evaluated params: (0.2, 7, 50, 1.0, 0.6, 0.1) | MAE: 913.7480
# Evaluated params: (0.2, 7, 50, 1.0, 0.6, 0.2) | MAE: 913.7480
# Evaluated params: (0.2, 7, 50, 1.0, 0.8, 0) | MAE: 957.1839
# Evaluated params: (0.2, 7, 50, 1.0, 0.8, 0.1) | MAE: 957.1839
# Evaluated params: (0.2, 7, 50, 1.0, 0.8, 0.2) | MAE: 957.1839
# Evaluated params: (0.2, 7, 50, 1.0, 1.0, 0) | MAE: 955.5158
# Evaluated params: (0.2, 7, 50, 1.0, 1.0, 0.1) | MAE: 955.5158
# Evaluated params: (0.2, 7, 50, 1.0, 1.0, 0.2) | MAE: 955.5158
# Evaluated params: (0.2, 7, 100, 0.6, 0.6, 0) | MAE: 803.8900
# Evaluated params: (0.2, 7, 100, 0.6, 0.6, 0.1) | MAE: 803.8900
# Evaluated params: (0.2, 7, 100, 0.6, 0.6, 0.2) | MAE: 803.8900
# Evaluated params: (0.2, 7, 100, 0.6, 0.8, 0) | MAE: 843.8846
# Evaluated params: (0.2, 7, 100, 0.6, 0.8, 0.1) | MAE: 843.8846
# Evaluated params: (0.2, 7, 100, 0.6, 0.8, 0.2) | MAE: 843.8846
# Evaluated params: (0.2, 7, 100, 0.6, 1.0, 0) | MAE: 869.8907
# Evaluated params: (0.2, 7, 100, 0.6, 1.0, 0.1) | MAE: 869.8907
# Evaluated params: (0.2, 7, 100, 0.6, 1.0, 0.2) | MAE: 869.8907
# Evaluated params: (0.2, 7, 100, 0.8, 0.6, 0) | MAE: 775.4853
# Evaluated params: (0.2, 7, 100, 0.8, 0.6, 0.1) | MAE: 775.4853
# Evaluated params: (0.2, 7, 100, 0.8, 0.6, 0.2) | MAE: 775.4853
# Evaluated params: (0.2, 7, 100, 0.8, 0.8, 0) | MAE: 978.9615
# Evaluated params: (0.2, 7, 100, 0.8, 0.8, 0.1) | MAE: 978.9615
# Evaluated params: (0.2, 7, 100, 0.8, 0.8, 0.2) | MAE: 978.9615
# Evaluated params: (0.2, 7, 100, 0.8, 1.0, 0) | MAE: 905.4075
# Evaluated params: (0.2, 7, 100, 0.8, 1.0, 0.1) | MAE: 905.4075
# Evaluated params: (0.2, 7, 100, 0.8, 1.0, 0.2) | MAE: 905.4075
# Evaluated params: (0.2, 7, 100, 1.0, 0.6, 0) | MAE: 921.0662
# Evaluated params: (0.2, 7, 100, 1.0, 0.6, 0.1) | MAE: 921.0662
# Evaluated params: (0.2, 7, 100, 1.0, 0.6, 0.2) | MAE: 921.0662
# Evaluated params: (0.2, 7, 100, 1.0, 0.8, 0) | MAE: 968.8336
# Evaluated params: (0.2, 7, 100, 1.0, 0.8, 0.1) | MAE: 968.8336
# Evaluated params: (0.2, 7, 100, 1.0, 0.8, 0.2) | MAE: 968.8336
# Evaluated params: (0.2, 7, 100, 1.0, 1.0, 0) | MAE: 964.4101
# Evaluated params: (0.2, 7, 100, 1.0, 1.0, 0.1) | MAE: 964.4097
# Evaluated params: (0.2, 7, 100, 1.0, 1.0, 0.2) | MAE: 964.4097
# Evaluated params: (0.2, 7, 150, 0.6, 0.6, 0) | MAE: 796.2595
# Evaluated params: (0.2, 7, 150, 0.6, 0.6, 0.1) | MAE: 796.2595
# Evaluated params: (0.2, 7, 150, 0.6, 0.6, 0.2) | MAE: 796.2595
# Evaluated params: (0.2, 7, 150, 0.6, 0.8, 0) | MAE: 851.8419
# Evaluated params: (0.2, 7, 150, 0.6, 0.8, 0.1) | MAE: 851.8419
# Evaluated params: (0.2, 7, 150, 0.6, 0.8, 0.2) | MAE: 851.8419
# Evaluated params: (0.2, 7, 150, 0.6, 1.0, 0) | MAE: 882.2527
# Evaluated params: (0.2, 7, 150, 0.6, 1.0, 0.1) | MAE: 882.2527
# Evaluated params: (0.2, 7, 150, 0.6, 1.0, 0.2) | MAE: 882.2527
# Evaluated params: (0.2, 7, 150, 0.8, 0.6, 0) | MAE: 780.0754
# Evaluated params: (0.2, 7, 150, 0.8, 0.6, 0.1) | MAE: 780.0754
# Evaluated params: (0.2, 7, 150, 0.8, 0.6, 0.2) | MAE: 780.0754
# Evaluated params: (0.2, 7, 150, 0.8, 0.8, 0) | MAE: 976.2537
# Evaluated params: (0.2, 7, 150, 0.8, 0.8, 0.1) | MAE: 976.2537
# Evaluated params: (0.2, 7, 150, 0.8, 0.8, 0.2) | MAE: 976.2537
# Evaluated params: (0.2, 7, 150, 0.8, 1.0, 0) | MAE: 907.9001
# Evaluated params: (0.2, 7, 150, 0.8, 1.0, 0.1) | MAE: 907.9005
# Evaluated params: (0.2, 7, 150, 0.8, 1.0, 0.2) | MAE: 907.9005
# Evaluated params: (0.2, 7, 150, 1.0, 0.6, 0) | MAE: 925.3949
# Evaluated params: (0.2, 7, 150, 1.0, 0.6, 0.1) | MAE: 925.4294
# Evaluated params: (0.2, 7, 150, 1.0, 0.6, 0.2) | MAE: 925.4294
# Evaluated params: (0.2, 7, 150, 1.0, 0.8, 0) | MAE: 972.2949
# Evaluated params: (0.2, 7, 150, 1.0, 0.8, 0.1) | MAE: 972.2949
# Evaluated params: (0.2, 7, 150, 1.0, 0.8, 0.2) | MAE: 972.2947
# Evaluated params: (0.2, 7, 150, 1.0, 1.0, 0) | MAE: 963.9985
# Evaluated params: (0.2, 7, 150, 1.0, 1.0, 0.1) | MAE: 963.9983
# Evaluated params: (0.2, 7, 150, 1.0, 1.0, 0.2) | MAE: 963.9983
#
# Best Parameters:
# learning_rate         0.010000
# max_depth             5.000000
# n_estimators        150.000000
# subsample             0.600000
# colsample_bytree      0.800000
# gamma                 0.000000
# mae                 570.213798
# Name: 138, dtype: float64
#
# Final Model MAE: 570.2138
#
# Final Predictions:
#                   Actual     Predicted
# Price Date
# 2024-01-01  13990.000000  13305.403320
# 2024-01-02  13916.157895  13305.403320
# 2024-01-03  14200.000000  13305.403320
# 2024-01-04  13751.700000  13329.665039
# 2024-01-05  13887.272727  13301.777344

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# Assuming `df` contains your data, and it is already prepared with features and target column
# Define train and test data
train_data = df.loc[:'2023-12-31']
test_data = df.loc['2024-01-01':'2024-10-31']

# Extract features and target
feature_columns = [col for col in df.columns if col != 'Modal Price (Rs./Quintal)']
X_train = train_data[feature_columns]
y_train = train_data['Modal Price (Rs./Quintal)']
X_test = test_data[feature_columns]
y_test = test_data['Modal Price (Rs./Quintal)']

# Best parameters from hyperparameter tuning
best_params = {
    'learning_rate': 0.01,
    'max_depth': 5,
    'n_estimators': 150,
    'subsample': 0.6,
    'colsample_bytree': 0.8,
    'gamma': 0.0,
    'objective': 'reg:squarederror',
    'random_state': 42
}

# Initialize the model with the best parameters
model = XGBRegressor(**best_params)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Add predictions to test data
test_data = test_data.copy()  # Avoid SettingWithCopyWarning
test_data['Predicted'] = y_pred

# Plot
plt.figure(figsize=(14, 7))

# Plot test data (actual values)
plt.plot(test_data.index, test_data['Modal Price (Rs./Quintal)'], label='Test (Actual)', color='green')

# Plot predictions
plt.plot(test_data.index, test_data['Predicted'], label='Predicted', color='red')

# Add title and labels
plt.title("Test and Predicted Modal Prices (Using Best Parameters)", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Modal Price (Rs./Quintal)", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()

# Metrics Calculation
def smape(y_true, y_pred):
    """Symmetric Mean Absolute Percentage Error"""
    non_zero_mask = (np.abs(y_true) + np.abs(y_pred)) > 0  # Avoid division by zero
    return 100 * np.mean(2 * np.abs(y_pred[non_zero_mask] - y_true[non_zero_mask]) /
                         (np.abs(y_true[non_zero_mask]) + np.abs(y_pred[non_zero_mask])))

def mdape(y_true, y_pred):
    """Median Absolute Percentage Error"""
    non_zero_mask = y_true != 0  # Avoid division by zero
    return 100 * np.median(np.abs((y_pred[non_zero_mask] - y_true[non_zero_mask]) / y_true[non_zero_mask]))

def gmrae(y_true, y_pred):
    """Geometric Mean Relative Absolute Error"""
    numerator = np.abs(y_true - y_pred)
    denominator = np.abs(y_true - np.mean(y_true))
    ratio = numerator / (denominator + 1e-10)  # Avoid division by zero
    return np.exp(np.mean(np.log(ratio + 1e-10)))

mae = mean_absolute_error(y_test, y_pred)
smape_val = smape(y_test.values, y_pred)
mdape_val = mdape(y_test.values, y_pred)
gmrae_val = gmrae(y_test.values, y_pred)

# Print metrics
print("Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Symmetric Mean Absolute Percentage Error (SMAPE): {smape_val:.4f}")
print(f"Median Absolute Percentage Error (MDAPE): {mdape_val:.4f}")
print(f"Geometric Mean Relative Absolute Error (GMRAE): {gmrae_val:.4f}")
# Out:
# Metrics:
# Mean Absolute Error (MAE): 570.2138
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.7766
# Median Absolute Percentage Error (MDAPE): 4.0812
# Geometric Mean Relative Absolute Error (GMRAE): 0.7338

# %%
def calculate_monthly_metrics(test_data, y_test, y_pred):
    # Ensure the index is in datetime format
    if not pd.api.types.is_datetime64_any_dtype(test_data.index):
        raise TypeError("The index of test_data must be a datetime type.")

    monthly_metrics = []

    # Group by 1-month periods using the index
    for period, period_data in test_data.groupby(pd.Grouper(freq='ME')):
        # Get the integer positions of the indices using get_indexer
        positions = test_data.index.get_indexer(period_data.index)

        # Get actual and predicted values for the current 1-month period
        period_y_true = y_test.iloc[positions]  # Use iloc for integer-based indexing
        period_y_pred = y_pred[positions]  # Use integer-based indexing for numpy array

        # Calculate the metrics for this period
        mae_period = mean_absolute_error(period_y_true, period_y_pred)
        smape_period = smape(period_y_true.values, period_y_pred)
        mdape_period = mdape(period_y_true.values, period_y_pred)
        gmrae_period = gmrae(period_y_true.values, period_y_pred)

        # Store the metrics for the 1-month period
        monthly_metrics.append({
            'Period': period,
            'MAE': mae_period,
            'SMAPE': smape_period,
            'MDAPE': mdape_period,
            'GMRAE': gmrae_period
        })

    return pd.DataFrame(monthly_metrics)

# Calculate monthly metrics
monthly_metrics_df = calculate_monthly_metrics(test_data, y_test, y_pred)

# Print the 1-month metrics
print("1-Month Period Metrics:")
print(monthly_metrics_df)
# Out:
# 1-Month Period Metrics:
#       Period         MAE     SMAPE     MDAPE     GMRAE
# 0 2024-01-31  490.449364  3.649305  3.679000  1.417853
# 1 2024-02-29  649.465648  5.023955  4.964954  2.767031
# 2 2024-03-31  416.356866  3.327938  2.799567  0.972715
# 3 2024-04-30  275.432161  2.247606  2.134398  1.157732
# 4 2024-05-31  486.075108  3.942594  3.599866  1.041968
# 5 2024-06-30  575.395577  5.094439  3.986629  1.629657
# 6 2024-07-31  652.829880  5.677885  5.096176  4.662472
# 7 2024-08-31  886.905131  7.542450  7.529509  5.922913
# 8 2024-09-30  463.383288  4.221029  3.038098  1.506273
# 9 2024-10-31  805.768441  7.038244  7.165767  3.471665
